# %% [markdown]
# # Modelling

# %% [markdown]
# ### Import Library Deep Learning

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, LSTM, Dense, Dropout, MaxPooling1D, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

print("✓ Pustaka Deep Learning Berhasil Dimuat!")
print("TensorFlow Version:", tf.__version__)
# Out:
# ✓ Pustaka Deep Learning Berhasil Dimuat!
# TensorFlow Version: 2.21.0

# %% [markdown]
# ### Memuat Data Hasil Ekstraksi

# %%
# Tentukan path lokasi folder tempat menyimpan file .npy
DATA_DIR = 'hasil_data_preparation'

# Load array koordinat spasio-temporal 3D
X_train = np.load(os.path.join(DATA_DIR, 'X_train_coor.npy'))
Y_train = np.load(os.path.join(DATA_DIR, 'Y_train_coor.npy'))
X_val = np.load(os.path.join(DATA_DIR, 'X_val_coor.npy'))
Y_val = np.load(os.path.join(DATA_DIR, 'Y_val_coor.npy'))

# Transformasi label integer (0-25) menjadi matriks biner One-Hot Encoding
num_classes = 26
Y_train_encoded = tf.keras.utils.to_categorical(Y_train, num_classes=num_classes)
Y_val_encoded = tf.keras.utils.to_categorical(Y_val, num_classes=num_classes)

print("=== VERIFIKASI DIMENSI MATRIKS UTAMA ===")
print(f"Shape X Latih      : {X_train.shape}  -> (3900 Sampel Sekuens, 30 Frame, 63 Koordinat)")
print(f"Shape Y Latih Target: {Y_train_encoded.shape}  -> (3900 Sampel, 26 Kelas Target)")
print(f"\nShape X Validasi   : {X_val.shape}  -> (780 Sampel Sekuens, 30 Frame, 63 Koordinat)")
print(f"Shape Y Val Target : {Y_val_encoded.shape}  -> (780 Sampel, 26 Kelas Target)")
# Out:
# === VERIFIKASI DIMENSI MATRIKS UTAMA ===
# Shape X Latih      : (3900, 30, 63)  -> (3900 Sampel Sekuens, 30 Frame, 63 Koordinat)
# Shape Y Latih Target: (3900, 26)  -> (3900 Sampel, 26 Kelas Target)
#
# Shape X Validasi   : (780, 30, 63)  -> (780 Sampel Sekuens, 30 Frame, 63 Koordinat)
# Shape Y Val Target : (780, 26)  -> (780 Sampel, 26 Kelas Target)

# %% [markdown]
# ### Perancangan Arsitektur Hybrid CRNN Spatio-Temporal

# %%
# ==========================================================
# 3.4.1.3 PERANCANGAN ARSITEKTUR HYBRID CRNN
# ==========================================================

def build_sibi_crnn(input_shape=(30, 63), num_classes=26):
    model = Sequential([
        
        # INPUT LAYER
        tf.keras.Input(shape=input_shape),

        # ==================================================
        # SPATIAL FEATURE EXTRACTION BLOCK (CONV1D)
        # ==================================================
        Conv1D(
            filters=64,
            kernel_size=3,
            activation='relu',
            padding='same'
        ),
        BatchNormalization(),
        MaxPooling1D(pool_size=2),
        Dropout(0.2),

        Conv1D(
            filters=128,
            kernel_size=3,
            activation='relu',
            padding='same'
        ),
        BatchNormalization(),
        MaxPooling1D(pool_size=2),
        Dropout(0.2),

        # ==================================================
        # TEMPORAL FEATURE EXTRACTION BLOCK (LSTM)
        # ==================================================
        LSTM(
            units=128,
            return_sequences=False
        ),
        Dropout(0.3),

        # ==================================================
        # CLASSIFIER BLOCK
        # ==================================================
        Dense(
            units=64,
            activation='relu'
        ),
        BatchNormalization(),
        Dropout(0.3),

        Dense(
            units=num_classes,
            activation='softmax'
        )
    ])

    return model


# Inisialisasi model CRNN
sibi_model = build_sibi_crnn(
    input_shape=(30, 63),
    num_classes=26
)

print("✓ Arsitektur Hybrid CRNN berhasil dibangun")
# Out:
# ✓ Arsitektur Hybrid CRNN berhasil dibangun

# %% [markdown]
# ### Konfigurasi Kompilasi Model

# %%
# ==========================================================
# 3.4.1.4 KONFIGURASI KOMPILASI MODEL
# ==========================================================

sibi_model.compile(
    optimizer=tf.keras.optimizers.Adam(
        learning_rate=0.001
    ),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

print("✓ Model berhasil dikompilasi")
print("Optimizer      : Adam")
print("Learning Rate  : 0.001")
print("Loss Function  : categorical_crossentropy")
print("Metric         : accuracy")
# Out:
# ✓ Model berhasil dikompilasi
# Optimizer      : Adam
# Learning Rate  : 0.001
# Loss Function  : categorical_crossentropy
# Metric         : accuracy

# %% [markdown]
# ### Verifikasi Struktur Arsitektur Model

# %%
# ==========================================================
# 3.4.1.5 VERIFIKASI STRUKTUR ARSITEKTUR MODEL
# ==========================================================

print("======================================")
print(" RINGKASAN ARSITEKTUR HYBRID CRNN ")
print("======================================\n")

sibi_model.summary()
# Out:
# ======================================
#  RINGKASAN ARSITEKTUR HYBRID CRNN
# ======================================
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_2 (Conv1D)               │ (None, 30, 64)         │        12,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_3           │ (None, 30, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_2 (MaxPooling1D)  │ (None, 15, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_4 (Dropout)             │ (None, 15, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_3 (Conv1D)               │ (None, 15, 128)        │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_4           │ (None, 15, 128)        │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_3 (MaxPooling1D)  │ (None, 7, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_5 (Dropout)             │ (None, 7, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_1 (LSTM)                   │ (None, 128)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_6 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_5           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_7 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 26)             │         1,690 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 179,418 (700.85 KB)
#  Trainable params: 178,906 (698.85 KB)
#  Non-trainable params: 512 (2.00 KB)

# %% [markdown]
# ### Konfigurasi Strategi Pelatihan Model

# %%
# ==========================================================
# 3.4.1.6 KONFIGURASI STRATEGI PELATIHAN MODEL
# ==========================================================

# Lokasi penyimpanan model terbaik
checkpoint_path = "hasil_modelling/best_sibi_crnn_model.keras"

callbacks_list = [

    # Menghentikan training ketika val_loss stagnan
    EarlyStopping(
        monitor='val_loss',
        patience=15,
        restore_best_weights=True,
        verbose=1
    ),

    # Menurunkan learning rate secara otomatis
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,
        min_lr=1e-6,
        verbose=1
    ),

    # Menyimpan model terbaik
    ModelCheckpoint(
        filepath=checkpoint_path,
        monitor='val_accuracy',
        save_best_only=True,
        verbose=1
    )
]

print("✓ Strategi pelatihan model berhasil dikonfigurasi")
print("✓ EarlyStopping aktif")
print("✓ ReduceLROnPlateau aktif")
print("✓ ModelCheckpoint aktif")
# Out:
# ✓ Strategi pelatihan model berhasil dikonfigurasi
# ✓ EarlyStopping aktif
# ✓ ReduceLROnPlateau aktif
# ✓ ModelCheckpoint aktif

# %% [markdown]
# ### Pelatihan Model Hybrid CRNN

# %%
# ==========================================================
# 3.4.1.7 PELATIHAN MODEL HYBRID CRNN
# ==========================================================

EPOCHS = 100
BATCH_SIZE = 32

print("=========================================")
print(" MEMULAI PROSES PELATIHAN MODEL CRNN ")
print("=========================================\n")

history = sibi_model.fit(
    X_train,
    Y_train_encoded,
    validation_data=(
        X_val,
        Y_val_encoded
    ),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=callbacks_list,
    shuffle=True,
    verbose=1
)

print("\n✓ Proses pelatihan model selesai")
# Out:
# =========================================
#  MEMULAI PROSES PELATIHAN MODEL CRNN
# =========================================
#
# Epoch 1/100
# 121/122 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4286 - loss: 2.0696
# Epoch 1: val_accuracy improved from None to 0.38077, saving model to hasil_modelling/best_sibi_crnn_model.keras
#
# Epoch 1: finished saving model to hasil_modelling/best_sibi_crnn_model.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 7s 19ms/step - accuracy: 0.6249 - loss: 1.3418 - val_accuracy: 0.3808 - val_loss: 2.7496 - learning_rate: 0.0010
# Epoch 2/100
# 121/122 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.8517 - loss: 0.5237
# Epoch 2: val_accuracy improved from 0.38077 to 0.45385, saving model to hasil_modelling/best_sibi_crnn_model.keras
#
# Epoch 2: finished saving model to hasil_modelling/best_sibi_crnn_model.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.8587 - loss: 0.4830 - val_accuracy: 0.4538 - val_loss: 2.2103 - learning_rate: 0.0010
# Epoch 3/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.8922 - loss: 0.3487
# Epoch 3: val_accuracy improved from 0.45385 to 0.74231, saving model to hasil_modelling/best_sibi_crnn_model.keras
#
# Epoch 3: finished saving model to hasil_modelling/best_sibi_crnn_model.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.8982 - loss: 0.3230 - val_accuracy: 0.7423 - val_loss: 0.8461 - learning_rate: 0.0010
# Epoch 4/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9124 - loss: 0.2760
# Epoch 4: val_accuracy improved from 0.74231 to 0.85000, saving model to hasil_modelling/best_sibi_crnn_model.keras
#
# Epoch 4: finished saving model to hasil_modelling/best_sibi_crnn_model.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9185 - loss: 0.2486 - val_accuracy: 0.8500 - val_loss: 0.3436 - learning_rate: 0.0010
# Epoch 5/100
# 120/122 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9203 - loss: 0.2178
# Epoch 5: val_accuracy did not improve from 0.85000
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9197 - loss: 0.2199 - val_accuracy: 0.8179 - val_loss: 0.4268 - learning_rate: 0.0010
# Epoch 6/100
# 121/122 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9285 - loss: 0.2115
# Epoch 6: val_accuracy improved from 0.85000 to 0.91282, saving model to hasil_modelling/best_sibi_crnn_model.keras
#
# Epoch 6: finished saving model to hasil_modelling/best_sibi_crnn_model.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9246 - loss: 0.2069 - val_accuracy: 0.9128 - val_loss: 0.2138 - learning_rate: 0.0010
# Epoch 7/100
# 121/122 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9214 - loss: 0.1963
# Epoch 7: val_accuracy did not improve from 0.91282
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9310 - loss: 0.1762 - val_accuracy: 0.8821 - val_loss: 0.2144 - learning_rate: 0.0010
# Epoch 8/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9291 - loss: 0.1834
# Epoch 8: val_accuracy did not improve from 0.91282
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9272 - loss: 0.1971 - val_accuracy: 0.7359 - val_loss: 0.6689 - learning_rate: 0.0010
# Epoch 9/100
# 118/122 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9130 - loss: 0.2371
# Epoch 9: val_accuracy did not improve from 0.91282
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9187 - loss: 0.2112 - val_accuracy: 0.9115 - val_loss: 0.2039 - learning_rate: 0.0010
# Epoch 10/100
# 121/122 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9191 - loss: 0.1947
# Epoch 10: val_accuracy did not improve from 0.91282
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9228 - loss: 0.1866 - val_accuracy: 0.7808 - val_loss: 0.6764 - learning_rate: 0.0010
# Epoch 11/100
# 118/122 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9248 - loss: 0.2067
# Epoch 11: val_accuracy did not improve from 0.91282
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9259 - loss: 0.1964 - val_accuracy: 0.8949 - val_loss: 0.2301 - learning_rate: 0.0010
# Epoch 12/100
# 120/122 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9339 - loss: 0.1621
# Epoch 12: val_accuracy did not improve from 0.91282
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9364 - loss: 0.1559 - val_accuracy: 0.9115 - val_loss: 0.1970 - learning_rate: 0.0010
# Epoch 13/100
# 120/122 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9428 - loss: 0.1483
# Epoch 13: val_accuracy did not improve from 0.91282
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 12ms/step - accuracy: 0.9395 - loss: 0.1527 - val_accuracy: 0.9090 - val_loss: 0.1901 - learning_rate: 0.0010
# Epoch 14/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9305 - loss: 0.1622
# Epoch 14: val_accuracy did not improve from 0.91282
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9249 - loss: 0.1804 - val_accuracy: 0.7013 - val_loss: 0.9822 - learning_rate: 0.0010
# Epoch 15/100
# 119/122 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9307 - loss: 0.1633
# Epoch 15: val_accuracy did not improve from 0.91282
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9331 - loss: 0.1588 - val_accuracy: 0.9128 - val_loss: 0.1839 - learning_rate: 0.0010
# Epoch 16/100
# 121/122 ━━━━━━━━━━━━━━━━━━━━ 0s 11ms/step - accuracy: 0.9369 - loss: 0.1480
# Epoch 16: val_accuracy did not improve from 0.91282
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 13ms/step - accuracy: 0.9367 - loss: 0.1497 - val_accuracy: 0.8744 - val_loss: 0.2479 - learning_rate: 0.0010
# Epoch 17/100
# 120/122 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9418 - loss: 0.1390
# Epoch 17: val_accuracy did not improve from 0.91282
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9408 - loss: 0.1410 - val_accuracy: 0.8846 - val_loss: 0.2437 - learning_rate: 0.0010
# Epoch 18/100
# 121/122 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9344 - loss: 0.1481
# Epoch 18: val_accuracy did not improve from 0.91282
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9356 - loss: 0.1450 - val_accuracy: 0.8769 - val_loss: 0.2856 - learning_rate: 0.0010
# Epoch 19/100
# 120/122 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9325 - loss: 0.1561
# Epoch 19: val_accuracy did not improve from 0.91282
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9308 - loss: 0.1622 - val_accuracy: 0.4833 - val_loss: 2.0672 - learning_rate: 0.0010
# Epoch 20/100
# 119/122 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9165 - loss: 0.2062
# Epoch 20: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 20: val_accuracy did not improve from 0.91282
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9223 - loss: 0.1932 - val_accuracy: 0.7654 - val_loss: 0.7161 - learning_rate: 0.0010
# Epoch 21/100
# 120/122 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9396 - loss: 0.1500
# Epoch 21: val_accuracy did not improve from 0.91282
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9395 - loss: 0.1481 - val_accuracy: 0.8910 - val_loss: 0.2583 - learning_rate: 5.0000e-04
# Epoch 22/100
# 120/122 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9374 - loss: 0.1301
# Epoch 22: val_accuracy did not improve from 0.91282
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9395 - loss: 0.1346 - val_accuracy: 0.9077 - val_loss: 0.1967 - learning_rate: 5.0000e-04
# Epoch 23/100
# 119/122 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9326 - loss: 0.1493
# Epoch 23: val_accuracy did not improve from 0.91282
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9387 - loss: 0.1389 - val_accuracy: 0.8359 - val_loss: 0.5955 - learning_rate: 5.0000e-04
# Epoch 24/100
# 118/122 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9447 - loss: 0.1310
# Epoch 24: val_accuracy did not improve from 0.91282
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9428 - loss: 0.1312 - val_accuracy: 0.9115 - val_loss: 0.1824 - learning_rate: 5.0000e-04
# Epoch 25/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9432 - loss: 0.1368
# Epoch 25: val_accuracy did not improve from 0.91282
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9459 - loss: 0.1302 - val_accuracy: 0.8885 - val_loss: 0.2141 - learning_rate: 5.0000e-04
# Epoch 26/100
# 119/122 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9427 - loss: 0.1274
# Epoch 26: val_accuracy improved from 0.91282 to 0.91410, saving model to hasil_modelling/best_sibi_crnn_model.keras
#
# Epoch 26: finished saving model to hasil_modelling/best_sibi_crnn_model.keras
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9441 - loss: 0.1245 - val_accuracy: 0.9141 - val_loss: 0.1802 - learning_rate: 5.0000e-04
# Epoch 27/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9497 - loss: 0.1195
# Epoch 27: val_accuracy did not improve from 0.91410
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 3s 22ms/step - accuracy: 0.9474 - loss: 0.1256 - val_accuracy: 0.8962 - val_loss: 0.2071 - learning_rate: 5.0000e-04
# Epoch 28/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9432 - loss: 0.1301
# Epoch 28: val_accuracy did not improve from 0.91410
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9446 - loss: 0.1287 - val_accuracy: 0.8821 - val_loss: 0.2333 - learning_rate: 5.0000e-04
# Epoch 29/100
# 120/122 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9411 - loss: 0.1342
# Epoch 29: val_accuracy did not improve from 0.91410
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9469 - loss: 0.1254 - val_accuracy: 0.8987 - val_loss: 0.2092 - learning_rate: 5.0000e-04
# Epoch 30/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9417 - loss: 0.1395
# Epoch 30: val_accuracy did not improve from 0.91410
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9413 - loss: 0.1342 - val_accuracy: 0.8705 - val_loss: 0.3421 - learning_rate: 5.0000e-04
# Epoch 31/100
# 120/122 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9412 - loss: 0.1429
# Epoch 31: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 31: val_accuracy did not improve from 0.91410
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9397 - loss: 0.1421 - val_accuracy: 0.9077 - val_loss: 0.1996 - learning_rate: 5.0000e-04
# Epoch 32/100
# 121/122 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9476 - loss: 0.1160
# Epoch 32: val_accuracy did not improve from 0.91410
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 19ms/step - accuracy: 0.9459 - loss: 0.1221 - val_accuracy: 0.9077 - val_loss: 0.1983 - learning_rate: 2.5000e-04
# Epoch 33/100
# 120/122 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9447 - loss: 0.1240
# Epoch 33: val_accuracy did not improve from 0.91410
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 18ms/step - accuracy: 0.9444 - loss: 0.1262 - val_accuracy: 0.9038 - val_loss: 0.2127 - learning_rate: 2.5000e-04
# Epoch 34/100
# 120/122 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9560 - loss: 0.1117
# Epoch 34: val_accuracy did not improve from 0.91410
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9513 - loss: 0.1192 - val_accuracy: 0.9115 - val_loss: 0.1955 - learning_rate: 2.5000e-04
# Epoch 35/100
# 121/122 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9432 - loss: 0.1177
# Epoch 35: val_accuracy did not improve from 0.91410
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9426 - loss: 0.1247 - val_accuracy: 0.9103 - val_loss: 0.1949 - learning_rate: 2.5000e-04
# Epoch 36/100
# 120/122 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9399 - loss: 0.1287
# Epoch 36: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 36: val_accuracy did not improve from 0.91410
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9421 - loss: 0.1237 - val_accuracy: 0.9141 - val_loss: 0.1841 - learning_rate: 2.5000e-04
# Epoch 37/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9446 - loss: 0.1145
# Epoch 37: val_accuracy did not improve from 0.91410
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 14ms/step - accuracy: 0.9449 - loss: 0.1189 - val_accuracy: 0.9077 - val_loss: 0.1972 - learning_rate: 1.2500e-04
# Epoch 38/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9493 - loss: 0.1074
# Epoch 38: val_accuracy did not improve from 0.91410
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 17ms/step - accuracy: 0.9446 - loss: 0.1186 - val_accuracy: 0.9115 - val_loss: 0.1890 - learning_rate: 1.2500e-04
# Epoch 39/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9466 - loss: 0.1235
# Epoch 39: val_accuracy did not improve from 0.91410
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9477 - loss: 0.1175 - val_accuracy: 0.9090 - val_loss: 0.1957 - learning_rate: 1.2500e-04
# Epoch 40/100
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9515 - loss: 0.1128
# Epoch 40: val_accuracy did not improve from 0.91410
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 15ms/step - accuracy: 0.9485 - loss: 0.1167 - val_accuracy: 0.9103 - val_loss: 0.1917 - learning_rate: 1.2500e-04
# Epoch 41/100
# 121/122 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9485 - loss: 0.1210
# Epoch 41: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 41: val_accuracy did not improve from 0.91410
# 122/122 ━━━━━━━━━━━━━━━━━━━━ 2s 16ms/step - accuracy: 0.9477 - loss: 0.1174 - val_accuracy: 0.9103 - val_loss: 0.1929 - learning_rate: 1.2500e-04
# Epoch 41: early stopping
# Restoring model weights from the end of the best epoch: 26.
#
# ✓ Proses pelatihan model selesai

# %% [markdown]
# # Evaluasi Model

# %% [markdown]
# ## Evaluasi Kuantitatif

# %% [markdown]
# ### Grafik Performa Accuracy Curve

# %%
import os
import matplotlib.pyplot as plt

# Pastikan folder tersedia
os.makedirs("hasil_modelling", exist_ok=True)

# Ambil histori akurasi
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

epochs_range = range(1, len(acc) + 1)

# ==========================================================
# GRAFIK ACCURACY
# ==========================================================

plt.figure(figsize=(8, 5))

plt.plot(
    epochs_range,
    acc,
    label='Training Accuracy',
    linewidth=2
)

plt.plot(
    epochs_range,
    val_acc,
    label='Validation Accuracy',
    linewidth=2
)

plt.title(
    'Grafik Akurasi Pelatihan Model Hybrid CRNN',
    fontsize=12,
    fontweight='bold'
)

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

plt.grid(
    True,
    linestyle='--',
    alpha=0.6
)

plt.tight_layout()

# Simpan gambar
file_acc = "hasil_modelling/grafik_accuracy_crnn.png"

plt.savefig(
    file_acc,
    dpi=300,
    bbox_inches='tight'
)

plt.show()

print(f"✓ Grafik Accuracy tersimpan pada: {file_acc}")
# Out:
# ✓ Grafik Accuracy tersimpan pada: hasil_modelling/grafik_accuracy_crnn.png

# %% [markdown]
# ### Grafik Performa Loss Curve

# %%
import os
import matplotlib.pyplot as plt

# Pastikan folder tersedia
os.makedirs("hasil_modelling", exist_ok=True)

# Ambil histori loss
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(1, len(loss) + 1)

# ==========================================================
# GRAFIK LOSS
# ==========================================================

plt.figure(figsize=(8, 5))

plt.plot(
    epochs_range,
    loss,
    label='Training Loss',
    linewidth=2
)

plt.plot(
    epochs_range,
    val_loss,
    label='Validation Loss',
    linewidth=2
)

plt.title(
    'Grafik Loss Pelatihan Model Hybrid CRNN',
    fontsize=12,
    fontweight='bold'
)

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.grid(
    True,
    linestyle='--',
    alpha=0.6
)

plt.tight_layout()

# Simpan gambar
file_loss = "hasil_modelling/grafik_loss_crnn.png"

plt.savefig(
    file_loss,
    dpi=300,
    bbox_inches='tight'
)

plt.show()

print(f"✓ Grafik Loss tersimpan pada: {file_loss}")
# Out:
# ✓ Grafik Loss tersimpan pada: hasil_modelling/grafik_loss_crnn.png

# %% [markdown]
# ## Evaluasi Performa Klasifikasi

# %%
# ==========================================================
# PERSIAPAN HASIL PREDIKSI MODEL
# ==========================================================

Y_pred_prob = sibi_model.predict(X_val)

Y_pred_labels = np.argmax(
    Y_pred_prob,
    axis=1
)

target_names = [
    chr(i) for i in range(65, 91)
]

print("✓ Hasil prediksi model berhasil dibuat")
# Out:
# 25/25 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step
# ✓ Hasil prediksi model berhasil dibuat

# %% [markdown]
# ### Overall Accuracy

# %%
from sklearn.metrics import accuracy_score

overall_accuracy = accuracy_score(
    Y_val,
    Y_pred_labels
)

print("===================================")
print(" OVERALL ACCURACY MODEL HYBRID CRNN ")
print("===================================")

print(f"Overall Accuracy : {overall_accuracy:.4f}")
print(f"Overall Accuracy : {overall_accuracy*100:.2f}%")
# Out:
# ===================================
#  OVERALL ACCURACY MODEL HYBRID CRNN
# ===================================
# Overall Accuracy : 0.9141
# Overall Accuracy : 91.41%

# %% [markdown]
# ### Classification Report

# %%
print("=======================================================")
# Laporan Evaluasi Klasifikasi Multi-Kelas Spatio-Temporal
print("      CLASSIFICATION REPORT MODEL HYBRID CRNN SIBI     ")
print("=======================================================\n")

print(
    classification_report(
        Y_val,
        Y_pred_labels,
        target_names=target_names
    )
)
# Out:
# =======================================================
#       CLASSIFICATION REPORT MODEL HYBRID CRNN SIBI
# =======================================================
#
#               precision    recall  f1-score   support
#
#            A       1.00      0.80      0.89        30
#            B       1.00      1.00      1.00        30
#            C       1.00      1.00      1.00        30
#            D       1.00      1.00      1.00        30
#            E       1.00      1.00      1.00        30
#            F       1.00      1.00      1.00        30
#            G       0.33      1.00      0.49        30
#            H       1.00      0.97      0.98        30
#            I       1.00      1.00      1.00        30
#            J       1.00      1.00      1.00        30
#            K       1.00      1.00      1.00        30
#            L       1.00      1.00      1.00        30
#            M       0.00      0.00      0.00        30
#            N       0.00      0.00      0.00        30
#            O       1.00      1.00      1.00        30
#            P       1.00      1.00      1.00        30
#            Q       1.00      1.00      1.00        30
#            R       0.97      1.00      0.98        30
#            S       1.00      1.00      1.00        30
#            T       1.00      1.00      1.00        30
#            U       1.00      1.00      1.00        30
#            V       1.00      1.00      1.00        30
#            W       1.00      1.00      1.00        30
#            X       1.00      1.00      1.00        30
#            Y       1.00      1.00      1.00        30
#            Z       1.00      1.00      1.00        30
#
#     accuracy                           0.91       780
#    macro avg       0.90      0.91      0.90       780
# weighted avg       0.90      0.91      0.90       780
# /home/zacx/Downloads/SKRIPSI/Aplikasi/env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/zacx/Downloads/SKRIPSI/Aplikasi/env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/zacx/Downloads/SKRIPSI/Aplikasi/env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# ### Bar Chart F1-Score CRNN

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

# 1. Ambil data report dalam bentuk dictionary (bukan string teks)
report_dict = classification_report(Y_val, Y_pred_labels, target_names=target_names, output_dict=True)

# 2. Ubah menjadi DataFrame pandas dan buang baris rangkuman (accuracy, macro avg, weighted avg)
df_report = pd.DataFrame(report_dict).transpose()
df_classes_only = df_report.loc[target_names] # Hanya mengambil baris A-Z

# 3. Plotting F1-Score tiap kelas menggunakan Bar Chart
plt.figure(figsize=(15, 6))
sns.barplot(
    x=df_classes_only.index, 
    y=df_classes_only['f1-score'], 
    palette='viridis'
)

plt.title('Grafik F1-Score Per Kelas Alfabet - Model CRNN SIBI', fontsize=14, fontweight='bold', pad=15)
plt.xlabel('Kelas Alfabet SIBI', fontsize=11)
plt.ylabel('F1-Score Value (0.0 - 1.0)', fontsize=11)
plt.ylim(0, 1.05) # Batas atas grafik
plt.grid(axis='y', linestyle='--', alpha=0.5)

# Tambahkan label nilai di atas setiap batang grafik
for i, val in enumerate(df_classes_only['f1-score']):
    plt.text(i, val + 0.01, f"{val:.2f}", ha='center', va='bottom', fontsize=9)

plt.tight_layout()

# Simpan gambar ke folder hasil_modelling
plt.savefig("hasil_modelling/crnn_f1_score_chart.png", dpi=300)
plt.show()

print("✓ Grafik batang F1-Score berhasil disimpan di 'hasil_modelling/crnn_f1_score_chart.png'")
# Out:
# /home/zacx/Downloads/SKRIPSI/Aplikasi/env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/zacx/Downloads/SKRIPSI/Aplikasi/env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/zacx/Downloads/SKRIPSI/Aplikasi/env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /tmp/ipykernel_20478/790546358.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# ✓ Grafik batang F1-Score berhasil disimpan di 'hasil_modelling/crnn_f1_score_chart.png'

# %% [markdown]
# ### Confusion Matrix

# %%
# 1. Hitung Confusion Matrix
cm = confusion_matrix(Y_val, Y_pred_labels)

# 2. Atur ukuran grafis gambar
plt.figure(figsize=(15, 12))

# 3. Gambar Heatmap menggunakan Seaborn
sns.heatmap(
    cm, 
    annot=True, 
    fmt='d', 
    cmap='Blues',
    xticklabels=target_names, 
    yticklabels=target_names,
    cbar=True,
    square=True
)

plt.title('Confusion Matrix Evaluasi Model Hybrid CRNN SIBI', fontsize=14, fontweight='bold', pad=20)
plt.xlabel('Label Prediksi Model', fontsize=12, labelpad=10)
plt.ylabel('Label Aktual (Grounded Truth)', fontsize=12, labelpad=10)
plt.xticks(rotation=0)
plt.yticks(rotation=0)
plt.tight_layout()

# 4. Simpan gambar secara fisik untuk disisipkan langsung ke Ms. Word Bab IV
plt.savefig('hasil_modelling/confusion_matrix_sibi.png', dpi=300)
plt.show()

print("✓ Grafik Confusion Matrix Berhasil Digambar dan Disimpan dengan nama 'confusion_matrix_sibi.png'!")
# Out:
# ✓ Grafik Confusion Matrix Berhasil Digambar dan Disimpan dengan nama 'confusion_matrix_sibi.png'!

# %% [markdown]
# # Pengujian

# %% [markdown]
# ### Prototype Deteksi SIBI

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
import mediapipe as mp

print("=== PROGRAM LIVE DEMO DETEKSI SIBI - CRNN (FIXED REAL-TIME) ===")

# 1. Muat Model Terbaik .keras
model_path = "hasil_modelling/best_sibi_crnn_model.keras"
if not os.path.exists(model_path):
    print(f" ERROR: File model '{model_path}' tidak ditemukan di folder ini!")
else:
    sibi_model = tf.keras.models.load_model(model_path)
    classes = [chr(i) for i in range(65, 91)] # ['A' s.d 'Z']
    print("✓ Model CRNN Berhasil Dimuat.")

    # 2. Inisialisasi Hand Landmarker Detector
    base_options = mp.tasks.BaseOptions(model_asset_path='hasil_data_preparation/hand_landmarker.task')
    options = mp.tasks.vision.HandLandmarkerOptions(
        base_options=base_options,
        num_hands=1,
        min_hand_detection_confidence=0.5
    )
    detector = mp.tasks.vision.HandLandmarker.create_from_options(options)
    print("✓ MediaPipe Hand Landmarker Berhasil Diinisialisasi.")

    # 3. Konfigurasi Menembak Langsung ke Hardware Utama (/dev/video0)
    cap = cv2.VideoCapture('/dev/video0', cv2.CAP_V4L2)
    cap.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
    cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)

    frame_buffer = []
    predicted_letter = "Mencari Tangan..."
    confidence_score = 0.0

    print("\nMembuka Kamera... Tekan tombol 'q' pada JENDELA VIDEO untuk menutup Live Demo.")

    if not cap.isOpened():
        print(" ERROR: Gagal mengakses '/dev/video0'.")
        print("Buka terminal lalu jalankan perintah: sudo chmod 666 /dev/video0")
    else:
        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                print(" Koneksi kamera terputus atau frame kosong.")
                break
                
            frame = cv2.flip(frame, 1)
            h, w, c = frame.shape
            
            img_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            mp_image = mp.Image(image_format=mp.ImageFormat.SRGB, data=img_rgb)
            
            # Deteksi Landmark koordinat oleh MediaPipe Tasks
            detection_result = detector.detect(mp_image)
            frame_features = [0.0] * 63
            
            if detection_result.hand_landmarks:
                hand_landmarks = detection_result.hand_landmarks[0]
                frame_features = []
                for lm in hand_landmarks:
                    frame_features.extend([lm.x, lm.y, lm.z])
                    cx, cy = int(lm.x * w), int(lm.y * h)
                    cv2.circle(frame, (cx, cy), 4, (0, 255, 0), -1)
                    
            frame_buffer.append(frame_features)
            
            if len(frame_buffer) > 30:
                frame_buffer.pop(0)
                
            # Prediksi Runtunan Waktu Spatio-Temporal jika buffer window (30 frame) sudah penuh
            if len(frame_buffer) == 30:
                input_tensor = np.array([frame_buffer], dtype=np.float32)
                preds = sibi_model.predict(input_tensor, verbose=0)
                idx = np.argmax(preds[0])
                predicted_letter = classes[idx]
                confidence_score = preds[0][idx] * 100

            # Gambar HUD Overlay Informasi Hasil Prediksi
            cv2.rectangle(frame, (10, 10), (350, 85), (0, 0, 0), -1)
            cv2.putText(frame, f"Prediksi Isyarat: {predicted_letter}", (20, 40), 
                        cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 255), 2, cv2.LINE_AA)
            cv2.putText(frame, f"Presentase Ketepatan : {confidence_score:.2f}%", (20, 70), 
                        cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2, cv2.LINE_AA)
            
            # Tampilkan window aplikasi
            cv2.imshow("Live Demo Deteksi Bahasa Isyarat SIBI - CRNN", frame)
            
            # Berhenti jika menekan tombol 'q'
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break

        cap.release()
        cv2.destroyAllWindows()
        print("\n✓ Live Demo Pengujian Berhasil Ditutup Bersih.")
# Out:
# === PROGRAM LIVE DEMO DETEKSI SIBI - CRNN (FIXED REAL-TIME) ===
# ✓ Model CRNN Berhasil Dimuat.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1785894241.045283   23573 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1785894241.049181   23587 gl_context.cc:385] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.2.8-0ubuntu0.24.04.2), renderer: Mesa Intel(R) UHD Graphics (ICL GT1)
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1785894241.094037   23575 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1785894241.135014   23578 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# ✓ MediaPipe Hand Landmarker Berhasil Diinisialisasi.
#
# Membuka Kamera... Tekan tombol 'q' pada JENDELA VIDEO untuk menutup Live Demo.
# W0000 00:00:1785894242.136075   23579 landmark_projection_calculator.cc:78] Using NORM_RECT without IMAGE_DIMENSIONS is only supported for the square ROI. Provide IMAGE_DIMENSIONS or use PROJECTION_MATRIX.
# QFontDatabase: Cannot find font directory /home/zacx/Downloads/SKRIPSI/Aplikasi/env/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/zacx/Downloads/SKRIPSI/Aplikasi/env/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/zacx/Downloads/SKRIPSI/Aplikasi/env/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/zacx/Downloads/SKRIPSI/Aplikasi/env/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/zacx/Downloads/SKRIPSI/Aplikasi/env/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# ✓ Live Demo Pengujian Berhasil Ditutup Bersih.
