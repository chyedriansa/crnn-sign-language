# %% [markdown]
# # Modelling

# %% [markdown]
# ### Import Library Deep Learning

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, LSTM, Dense, Dropout, MaxPooling1D, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

print("✓ Pustaka Deep Learning Berhasil Dimuat!")
print("TensorFlow Version:", tf.__version__)
# Out:
# ✓ Pustaka Deep Learning Berhasil Dimuat!
# TensorFlow Version: 2.21.0

# %% [markdown]
# ### Memuat Data Hasil Ekstraksi

# %%
# Tentukan path lokasi folder tempat menyimpan file .npy
DATA_DIR = '../hasil_data_preparation/rasio_90_10/'

# Load array koordinat spasio-temporal 3D
X_train = np.load(os.path.join(DATA_DIR, 'X_train_coor.npy'))
Y_train = np.load(os.path.join(DATA_DIR, 'Y_train_coor.npy'))
X_val = np.load(os.path.join(DATA_DIR, 'X_val_coor.npy'))
Y_val = np.load(os.path.join(DATA_DIR, 'Y_val_coor.npy'))

# Transformasi label integer (0-25) menjadi matriks biner One-Hot Encoding
num_classes = 26
Y_train_encoded = tf.keras.utils.to_categorical(Y_train, num_classes=num_classes)
Y_val_encoded = tf.keras.utils.to_categorical(Y_val, num_classes=num_classes)

print("=== VERIFIKASI DIMENSI MATRIKS UTAMA ===")
print(f"Shape X Latih      : {X_train.shape}")
print(f"Shape Y Latih Target: {Y_train_encoded.shape}")
print(f"\nShape X Validasi   : {X_val.shape}")
print(f"Shape Y Val Target : {Y_val_encoded.shape})")
# Out:
# === VERIFIKASI DIMENSI MATRIKS UTAMA ===
# Shape X Latih      : (4212, 30, 63)
# Shape Y Latih Target: (4212, 26)
#
# Shape X Validasi   : (468, 30, 63)
# Shape Y Val Target : (468, 26))

# %% [markdown]
# ### Perancangan Arsitektur Hybrid CRNN Spatio-Temporal

# %%
# ==========================================================
# 3.4.1.3 PERANCANGAN ARSITEKTUR HYBRID CRNN
# ==========================================================

def build_sibi_crnn(input_shape=(30, 63), num_classes=26):
    model = Sequential([
        
        # INPUT LAYER
        tf.keras.Input(shape=input_shape),

        # ==================================================
        # SPATIAL FEATURE EXTRACTION BLOCK (CONV1D)
        # ==================================================
        Conv1D(
            filters=64,
            kernel_size=3,
            activation='relu',
            padding='same'
        ),
        BatchNormalization(),
        MaxPooling1D(pool_size=2),
        Dropout(0.2),

        Conv1D(
            filters=128,
            kernel_size=3,
            activation='relu',
            padding='same'
        ),
        BatchNormalization(),
        MaxPooling1D(pool_size=2),
        Dropout(0.2),

        # ==================================================
        # TEMPORAL FEATURE EXTRACTION BLOCK (LSTM)
        # ==================================================
        LSTM(
            units=128,
            return_sequences=False
        ),
        Dropout(0.3),

        # ==================================================
        # CLASSIFIER BLOCK
        # ==================================================
        Dense(
            units=64,
            activation='relu'
        ),
        BatchNormalization(),
        Dropout(0.3),

        Dense(
            units=num_classes,
            activation='softmax'
        )
    ])

    return model


# Inisialisasi model CRNN
sibi_model = build_sibi_crnn(
    input_shape=(30, 63),
    num_classes=26
)

print("✓ Arsitektur Hybrid CRNN berhasil dibangun")
# Out:
# ✓ Arsitektur Hybrid CRNN berhasil dibangun

# %% [markdown]
# ### Konfigurasi Kompilasi Model

# %%
# ==========================================================
# 3.4.1.4 KONFIGURASI KOMPILASI MODEL
# ==========================================================

sibi_model.compile(
    optimizer=tf.keras.optimizers.Adam(
        learning_rate=0.001
    ),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

print("✓ Model berhasil dikompilasi")
print("Optimizer      : Adam")
print("Learning Rate  : 0.001")
print("Loss Function  : categorical_crossentropy")
print("Metric         : accuracy")
# Out:
# ✓ Model berhasil dikompilasi
# Optimizer      : Adam
# Learning Rate  : 0.001
# Loss Function  : categorical_crossentropy
# Metric         : accuracy

# %% [markdown]
# ### Verifikasi Struktur Arsitektur Model

# %%
# ==========================================================
# 3.4.1.5 VERIFIKASI STRUKTUR ARSITEKTUR MODEL
# ==========================================================

print("======================================")
print(" RINGKASAN ARSITEKTUR HYBRID CRNN ")
print("======================================\n")

sibi_model.summary()
# Out:
# ======================================
#  RINGKASAN ARSITEKTUR HYBRID CRNN
# ======================================
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d_4 (Conv1D)               │ (None, 30, 64)         │        12,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_6           │ (None, 30, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_4 (MaxPooling1D)  │ (None, 15, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_8 (Dropout)             │ (None, 15, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_5 (Conv1D)               │ (None, 15, 128)        │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_7           │ (None, 15, 128)        │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_5 (MaxPooling1D)  │ (None, 7, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_9 (Dropout)             │ (None, 7, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_2 (LSTM)                   │ (None, 128)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_10 (Dropout)            │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_8           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_11 (Dropout)            │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_5 (Dense)                 │ (None, 26)             │         1,690 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 179,418 (700.85 KB)
#  Trainable params: 178,906 (698.85 KB)
#  Non-trainable params: 512 (2.00 KB)

# %% [markdown]
# ### Konfigurasi Strategi Pelatihan Model

# %%
# ==========================================================
# 3.4.1.6 KONFIGURASI STRATEGI PELATIHAN MODEL
# ==========================================================

# Lokasi penyimpanan model terbaik
checkpoint_path = "hasil_modelling/rasio_90_10/best_sibi_crnn_model.keras"

callbacks_list = [

    # Menghentikan training ketika val_loss stagnan
    EarlyStopping(
        monitor='val_loss',
        patience=15,
        restore_best_weights=True,
        verbose=1
    ),

    # Menurunkan learning rate secara otomatis
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,
        min_lr=1e-6,
        verbose=1
    ),

    # Menyimpan model terbaik
    ModelCheckpoint(
        filepath=checkpoint_path,
        monitor='val_accuracy',
        save_best_only=True,
        verbose=1
    )
]

print("✓ Strategi pelatihan model berhasil dikonfigurasi")
print("✓ EarlyStopping aktif")
print("✓ ReduceLROnPlateau aktif")
print("✓ ModelCheckpoint aktif")
# Out:
# ✓ Strategi pelatihan model berhasil dikonfigurasi
# ✓ EarlyStopping aktif
# ✓ ReduceLROnPlateau aktif
# ✓ ModelCheckpoint aktif

# %% [markdown]
# ### Pelatihan Model Hybrid CRNN

# %%
# ==========================================================
# 3.4.1.7 PELATIHAN MODEL HYBRID CRNN
# ==========================================================

EPOCHS = 100
BATCH_SIZE = 64

print("=========================================")
print(" MEMULAI PROSES PELATIHAN MODEL CRNN ")
print("=========================================\n")

history = sibi_model.fit(
    X_train,
    Y_train_encoded,
    validation_data=(
        X_val,
        Y_val_encoded
    ),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=callbacks_list,
    shuffle=True,
    verbose=1
)

print("\n✓ Proses pelatihan model selesai")
# Out:
# =========================================
#  MEMULAI PROSES PELATIHAN MODEL CRNN
# =========================================
#
# Epoch 1/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3585 - loss: 2.3594
# Epoch 1: val_accuracy improved from None to 0.21581, saving model to hasil_modelling/rasio_90_10/best_sibi_crnn_model.keras
#
# Epoch 1: finished saving model to hasil_modelling/rasio_90_10/best_sibi_crnn_model.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 6s 26ms/step - accuracy: 0.5672 - loss: 1.5460 - val_accuracy: 0.2158 - val_loss: 2.9650 - learning_rate: 0.0010
# Epoch 2/100
# 65/66 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8118 - loss: 0.6428
# Epoch 2: val_accuracy did not improve from 0.21581
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8208 - loss: 0.5787 - val_accuracy: 0.1795 - val_loss: 2.7495 - learning_rate: 0.0010
# Epoch 3/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.8617 - loss: 0.4358
# Epoch 3: val_accuracy improved from 0.21581 to 0.22436, saving model to hasil_modelling/rasio_90_10/best_sibi_crnn_model.keras
#
# Epoch 3: finished saving model to hasil_modelling/rasio_90_10/best_sibi_crnn_model.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.8637 - loss: 0.4167 - val_accuracy: 0.2244 - val_loss: 2.6042 - learning_rate: 0.0010
# Epoch 4/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8886 - loss: 0.3343
# Epoch 4: val_accuracy improved from 0.22436 to 0.34188, saving model to hasil_modelling/rasio_90_10/best_sibi_crnn_model.keras
#
# Epoch 4: finished saving model to hasil_modelling/rasio_90_10/best_sibi_crnn_model.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8844 - loss: 0.3387 - val_accuracy: 0.3419 - val_loss: 2.3150 - learning_rate: 0.0010
# Epoch 5/100
# 63/66 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8871 - loss: 0.3151
# Epoch 5: val_accuracy improved from 0.34188 to 0.65171, saving model to hasil_modelling/rasio_90_10/best_sibi_crnn_model.keras
#
# Epoch 5: finished saving model to hasil_modelling/rasio_90_10/best_sibi_crnn_model.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.8925 - loss: 0.3057 - val_accuracy: 0.6517 - val_loss: 1.4047 - learning_rate: 0.0010
# Epoch 6/100
# 65/66 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9013 - loss: 0.2730
# Epoch 6: val_accuracy improved from 0.65171 to 0.67521, saving model to hasil_modelling/rasio_90_10/best_sibi_crnn_model.keras
#
# Epoch 6: finished saving model to hasil_modelling/rasio_90_10/best_sibi_crnn_model.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9055 - loss: 0.2612 - val_accuracy: 0.6752 - val_loss: 1.1515 - learning_rate: 0.0010
# Epoch 7/100
# 62/66 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9152 - loss: 0.2431
# Epoch 7: val_accuracy improved from 0.67521 to 0.73932, saving model to hasil_modelling/rasio_90_10/best_sibi_crnn_model.keras
#
# Epoch 7: finished saving model to hasil_modelling/rasio_90_10/best_sibi_crnn_model.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9122 - loss: 0.2469 - val_accuracy: 0.7393 - val_loss: 0.9617 - learning_rate: 0.0010
# Epoch 8/100
# 64/66 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9139 - loss: 0.2445
# Epoch 8: val_accuracy improved from 0.73932 to 0.76282, saving model to hasil_modelling/rasio_90_10/best_sibi_crnn_model.keras
#
# Epoch 8: finished saving model to hasil_modelling/rasio_90_10/best_sibi_crnn_model.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9129 - loss: 0.2413 - val_accuracy: 0.7628 - val_loss: 0.7479 - learning_rate: 0.0010
# Epoch 9/100
# 63/66 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9260 - loss: 0.2148
# Epoch 9: val_accuracy improved from 0.76282 to 0.78632, saving model to hasil_modelling/rasio_90_10/best_sibi_crnn_model.keras
#
# Epoch 9: finished saving model to hasil_modelling/rasio_90_10/best_sibi_crnn_model.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9228 - loss: 0.2147 - val_accuracy: 0.7863 - val_loss: 0.7834 - learning_rate: 0.0010
# Epoch 10/100
# 63/66 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9292 - loss: 0.2016
# Epoch 10: val_accuracy did not improve from 0.78632
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9259 - loss: 0.2047 - val_accuracy: 0.7650 - val_loss: 0.6692 - learning_rate: 0.0010
# Epoch 11/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9178 - loss: 0.2201
# Epoch 11: val_accuracy did not improve from 0.78632
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9226 - loss: 0.2024 - val_accuracy: 0.7735 - val_loss: 0.6679 - learning_rate: 0.0010
# Epoch 12/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9308 - loss: 0.1848
# Epoch 12: val_accuracy improved from 0.78632 to 0.79915, saving model to hasil_modelling/rasio_90_10/best_sibi_crnn_model.keras
#
# Epoch 12: finished saving model to hasil_modelling/rasio_90_10/best_sibi_crnn_model.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9281 - loss: 0.1884 - val_accuracy: 0.7991 - val_loss: 0.6725 - learning_rate: 0.0010
# Epoch 13/100
# 64/66 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9288 - loss: 0.1861
# Epoch 13: val_accuracy improved from 0.79915 to 0.80769, saving model to hasil_modelling/rasio_90_10/best_sibi_crnn_model.keras
#
# Epoch 13: finished saving model to hasil_modelling/rasio_90_10/best_sibi_crnn_model.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9290 - loss: 0.1851 - val_accuracy: 0.8077 - val_loss: 0.6046 - learning_rate: 0.0010
# Epoch 14/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9213 - loss: 0.1883
# Epoch 14: val_accuracy did not improve from 0.80769
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9266 - loss: 0.1833 - val_accuracy: 0.7799 - val_loss: 0.6446 - learning_rate: 0.0010
# Epoch 15/100
# 64/66 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9250 - loss: 0.1976
# Epoch 15: val_accuracy did not improve from 0.80769
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9200 - loss: 0.2045 - val_accuracy: 0.7671 - val_loss: 0.7307 - learning_rate: 0.0010
# Epoch 16/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.9249 - loss: 0.1948
# Epoch 16: val_accuracy did not improve from 0.80769
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9259 - loss: 0.1959 - val_accuracy: 0.7179 - val_loss: 0.9395 - learning_rate: 0.0010
# Epoch 17/100
# 63/66 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9297 - loss: 0.1857
# Epoch 17: val_accuracy did not improve from 0.80769
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9271 - loss: 0.1950 - val_accuracy: 0.7543 - val_loss: 1.0361 - learning_rate: 0.0010
# Epoch 18/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9241 - loss: 0.1967
# Epoch 18: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 18: val_accuracy did not improve from 0.80769
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9200 - loss: 0.2135 - val_accuracy: 0.5470 - val_loss: 1.7237 - learning_rate: 0.0010
# Epoch 19/100
# 64/66 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9204 - loss: 0.2191
# Epoch 19: val_accuracy did not improve from 0.80769
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9238 - loss: 0.1995 - val_accuracy: 0.8077 - val_loss: 0.4670 - learning_rate: 5.0000e-04
# Epoch 20/100
# 64/66 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9264 - loss: 0.1894
# Epoch 20: val_accuracy improved from 0.80769 to 0.82692, saving model to hasil_modelling/rasio_90_10/best_sibi_crnn_model.keras
#
# Epoch 20: finished saving model to hasil_modelling/rasio_90_10/best_sibi_crnn_model.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9271 - loss: 0.1822 - val_accuracy: 0.8269 - val_loss: 0.5145 - learning_rate: 5.0000e-04
# Epoch 21/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9331 - loss: 0.1642
# Epoch 21: val_accuracy did not improve from 0.82692
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9304 - loss: 0.1766 - val_accuracy: 0.8141 - val_loss: 0.5003 - learning_rate: 5.0000e-04
# Epoch 22/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.9289 - loss: 0.1792
# Epoch 22: val_accuracy improved from 0.82692 to 0.84188, saving model to hasil_modelling/rasio_90_10/best_sibi_crnn_model.keras
#
# Epoch 22: finished saving model to hasil_modelling/rasio_90_10/best_sibi_crnn_model.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9309 - loss: 0.1724 - val_accuracy: 0.8419 - val_loss: 0.4238 - learning_rate: 5.0000e-04
# Epoch 23/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9340 - loss: 0.1597
# Epoch 23: val_accuracy improved from 0.84188 to 0.85043, saving model to hasil_modelling/rasio_90_10/best_sibi_crnn_model.keras
#
# Epoch 23: finished saving model to hasil_modelling/rasio_90_10/best_sibi_crnn_model.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9290 - loss: 0.1691 - val_accuracy: 0.8504 - val_loss: 0.3829 - learning_rate: 5.0000e-04
# Epoch 24/100
# 63/66 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9309 - loss: 0.1663
# Epoch 24: val_accuracy did not improve from 0.85043
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9283 - loss: 0.1734 - val_accuracy: 0.8462 - val_loss: 0.4247 - learning_rate: 5.0000e-04
# Epoch 25/100
# 65/66 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9281 - loss: 0.1759
# Epoch 25: val_accuracy improved from 0.85043 to 0.85256, saving model to hasil_modelling/rasio_90_10/best_sibi_crnn_model.keras
#
# Epoch 25: finished saving model to hasil_modelling/rasio_90_10/best_sibi_crnn_model.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9314 - loss: 0.1690 - val_accuracy: 0.8526 - val_loss: 0.3548 - learning_rate: 5.0000e-04
# Epoch 26/100
# 64/66 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9324 - loss: 0.1704
# Epoch 26: val_accuracy did not improve from 0.85256
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9278 - loss: 0.1724 - val_accuracy: 0.8205 - val_loss: 0.4561 - learning_rate: 5.0000e-04
# Epoch 27/100
# 65/66 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9322 - loss: 0.1643
# Epoch 27: val_accuracy did not improve from 0.85256
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9297 - loss: 0.1692 - val_accuracy: 0.8205 - val_loss: 0.4381 - learning_rate: 5.0000e-04
# Epoch 28/100
# 65/66 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9328 - loss: 0.1684
# Epoch 28: val_accuracy did not improve from 0.85256
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9300 - loss: 0.1728 - val_accuracy: 0.8269 - val_loss: 0.4353 - learning_rate: 5.0000e-04
# Epoch 29/100
# 63/66 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9286 - loss: 0.1705
# Epoch 29: val_accuracy improved from 0.85256 to 0.85684, saving model to hasil_modelling/rasio_90_10/best_sibi_crnn_model.keras
#
# Epoch 29: finished saving model to hasil_modelling/rasio_90_10/best_sibi_crnn_model.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 14ms/step - accuracy: 0.9283 - loss: 0.1687 - val_accuracy: 0.8568 - val_loss: 0.3673 - learning_rate: 5.0000e-04
# Epoch 30/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.9269 - loss: 0.1606
# Epoch 30: val_accuracy improved from 0.85684 to 0.86538, saving model to hasil_modelling/rasio_90_10/best_sibi_crnn_model.keras
#
# Epoch 30: finished saving model to hasil_modelling/rasio_90_10/best_sibi_crnn_model.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 15ms/step - accuracy: 0.9290 - loss: 0.1643 - val_accuracy: 0.8654 - val_loss: 0.3423 - learning_rate: 5.0000e-04
# Epoch 31/100
# 63/66 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9322 - loss: 0.1723
# Epoch 31: val_accuracy did not improve from 0.86538
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9309 - loss: 0.1678 - val_accuracy: 0.8462 - val_loss: 0.5091 - learning_rate: 5.0000e-04
# Epoch 32/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9274 - loss: 0.1800
# Epoch 32: val_accuracy did not improve from 0.86538
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9309 - loss: 0.1698 - val_accuracy: 0.8504 - val_loss: 0.5068 - learning_rate: 5.0000e-04
# Epoch 33/100
# 63/66 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9303 - loss: 0.1602
# Epoch 33: val_accuracy improved from 0.86538 to 0.88034, saving model to hasil_modelling/rasio_90_10/best_sibi_crnn_model.keras
#
# Epoch 33: finished saving model to hasil_modelling/rasio_90_10/best_sibi_crnn_model.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9314 - loss: 0.1711 - val_accuracy: 0.8803 - val_loss: 0.2930 - learning_rate: 5.0000e-04
# Epoch 34/100
# 64/66 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9264 - loss: 0.1695
# Epoch 34: val_accuracy improved from 0.88034 to 0.88248, saving model to hasil_modelling/rasio_90_10/best_sibi_crnn_model.keras
#
# Epoch 34: finished saving model to hasil_modelling/rasio_90_10/best_sibi_crnn_model.keras
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9302 - loss: 0.1671 - val_accuracy: 0.8825 - val_loss: 0.3463 - learning_rate: 5.0000e-04
# Epoch 35/100
# 63/66 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9301 - loss: 0.1740
# Epoch 35: val_accuracy did not improve from 0.88248
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9292 - loss: 0.1717 - val_accuracy: 0.8162 - val_loss: 0.4711 - learning_rate: 5.0000e-04
# Epoch 36/100
# 63/66 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9295 - loss: 0.1733
# Epoch 36: val_accuracy did not improve from 0.88248
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9309 - loss: 0.1676 - val_accuracy: 0.8547 - val_loss: 0.4622 - learning_rate: 5.0000e-04
# Epoch 37/100
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9277 - loss: 0.1663
# Epoch 37: val_accuracy did not improve from 0.88248
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9285 - loss: 0.1720 - val_accuracy: 0.8248 - val_loss: 0.6233 - learning_rate: 5.0000e-04
# Epoch 38/100
# 65/66 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9361 - loss: 0.1622
# Epoch 38: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 38: val_accuracy did not improve from 0.88248
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9326 - loss: 0.1653 - val_accuracy: 0.8098 - val_loss: 0.6457 - learning_rate: 5.0000e-04
# Epoch 39/100
# 65/66 ━━━━━━━━━━━━━━━━━━━━ 0s 21ms/step - accuracy: 0.9456 - loss: 0.1489
# Epoch 39: val_accuracy did not improve from 0.88248
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.9330 - loss: 0.1666 - val_accuracy: 0.8440 - val_loss: 0.4658 - learning_rate: 2.5000e-04
# Epoch 40/100
# 64/66 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9320 - loss: 0.1681
# Epoch 40: val_accuracy did not improve from 0.88248
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9307 - loss: 0.1670 - val_accuracy: 0.8462 - val_loss: 0.4367 - learning_rate: 2.5000e-04
# Epoch 41/100
# 65/66 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9311 - loss: 0.1688
# Epoch 41: val_accuracy did not improve from 0.88248
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9314 - loss: 0.1623 - val_accuracy: 0.8355 - val_loss: 0.4726 - learning_rate: 2.5000e-04
# Epoch 42/100
# 64/66 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.9334 - loss: 0.1663
# Epoch 42: val_accuracy did not improve from 0.88248
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9347 - loss: 0.1629 - val_accuracy: 0.8397 - val_loss: 0.4864 - learning_rate: 2.5000e-04
# Epoch 43/100
# 65/66 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9247 - loss: 0.1829
# Epoch 43: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 43: val_accuracy did not improve from 0.88248
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9309 - loss: 0.1639 - val_accuracy: 0.8590 - val_loss: 0.4211 - learning_rate: 2.5000e-04
# Epoch 44/100
# 65/66 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9343 - loss: 0.1619
# Epoch 44: val_accuracy did not improve from 0.88248
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9330 - loss: 0.1609 - val_accuracy: 0.8654 - val_loss: 0.4235 - learning_rate: 1.2500e-04
# Epoch 45/100
# 65/66 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9258 - loss: 0.1669
# Epoch 45: val_accuracy did not improve from 0.88248
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9311 - loss: 0.1622 - val_accuracy: 0.8654 - val_loss: 0.4126 - learning_rate: 1.2500e-04
# Epoch 46/100
# 65/66 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9347 - loss: 0.1637
# Epoch 46: val_accuracy did not improve from 0.88248
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 17ms/step - accuracy: 0.9321 - loss: 0.1636 - val_accuracy: 0.8632 - val_loss: 0.4239 - learning_rate: 1.2500e-04
# Epoch 47/100
# 64/66 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9256 - loss: 0.1706
# Epoch 47: val_accuracy did not improve from 0.88248
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9302 - loss: 0.1614 - val_accuracy: 0.8632 - val_loss: 0.4383 - learning_rate: 1.2500e-04
# Epoch 48/100
# 65/66 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9321 - loss: 0.1641
# Epoch 48: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 48: val_accuracy did not improve from 0.88248
# 66/66 ━━━━━━━━━━━━━━━━━━━━ 1s 16ms/step - accuracy: 0.9311 - loss: 0.1607 - val_accuracy: 0.8611 - val_loss: 0.4352 - learning_rate: 1.2500e-04
# Epoch 48: early stopping
# Restoring model weights from the end of the best epoch: 33.
#
# ✓ Proses pelatihan model selesai

# %% [markdown]
# # Evaluasi Model

# %% [markdown]
# ## Evaluasi Kuantitatif

# %% [markdown]
# ### Grafik Performa Accuracy Curve

# %%
import os
import matplotlib.pyplot as plt

# Pastikan folder tersedia
os.makedirs("hasil_modelling/rasio_90_10", exist_ok=True)

# Ambil histori akurasi
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

epochs_range = range(1, len(acc) + 1)

# ==========================================================
# GRAFIK ACCURACY
# ==========================================================

plt.figure(figsize=(8, 5))

plt.plot(
    epochs_range,
    acc,
    label='Training Accuracy',
    linewidth=2
)

plt.plot(
    epochs_range,
    val_acc,
    label='Validation Accuracy',
    linewidth=2
)

plt.title(
    'Grafik Akurasi Pelatihan Model Hybrid CRNN',
    fontsize=12,
    fontweight='bold'
)

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

plt.grid(
    True,
    linestyle='--',
    alpha=0.6
)

plt.tight_layout()

# Simpan gambar
file_acc = "hasil_modelling/rasio_90_10/grafik_accuracy_crnn.png"

plt.savefig(
    file_acc,
    dpi=300,
    bbox_inches='tight'
)

plt.show()

print(f"✓ Grafik Accuracy tersimpan pada: {file_acc}")
# Out:
# ✓ Grafik Accuracy tersimpan pada: hasil_modelling/rasio_90_10/grafik_accuracy_crnn.png

# %% [markdown]
# ### Grafik Performa Loss Curve

# %%
import os
import matplotlib.pyplot as plt

# Pastikan folder tersedia
os.makedirs("hasil_modelling/rasio_90_10", exist_ok=True)

# Ambil histori loss
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(1, len(loss) + 1)

# ==========================================================
# GRAFIK LOSS
# ==========================================================

plt.figure(figsize=(8, 5))

plt.plot(
    epochs_range,
    loss,
    label='Training Loss',
    linewidth=2
)

plt.plot(
    epochs_range,
    val_loss,
    label='Validation Loss',
    linewidth=2
)

plt.title(
    'Grafik Loss Pelatihan Model Hybrid CRNN',
    fontsize=12,
    fontweight='bold'
)

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.grid(
    True,
    linestyle='--',
    alpha=0.6
)

plt.tight_layout()

# Simpan gambar
file_loss = "hasil_modelling/rasio_90_10/grafik_loss_crnn.png"

plt.savefig(
    file_loss,
    dpi=300,
    bbox_inches='tight'
)

plt.show()

print(f"✓ Grafik Loss tersimpan pada: {file_loss}")
# Out:
# ✓ Grafik Loss tersimpan pada: hasil_modelling/rasio_90_10/grafik_loss_crnn.png

# %% [markdown]
# ## Evaluasi Performa Klasifikasi

# %%
# ==========================================================
# PERSIAPAN HASIL PREDIKSI MODEL
# ==========================================================

Y_pred_prob = sibi_model.predict(X_val)

Y_pred_labels = np.argmax(
    Y_pred_prob,
    axis=1
)

target_names = [
    chr(i) for i in range(65, 91)
]

print("✓ Hasil prediksi model berhasil dibuat")
# Out:
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step
# ✓ Hasil prediksi model berhasil dibuat

# %% [markdown]
# ### Overall Accuracy

# %%
from sklearn.metrics import accuracy_score

overall_accuracy = accuracy_score(
    Y_val,
    Y_pred_labels
)

print("===================================")
print(" OVERALL ACCURACY MODEL HYBRID CRNN ")
print("===================================")

print(f"Overall Accuracy : {overall_accuracy:.4f}")
print(f"Overall Accuracy : {overall_accuracy*100:.2f}%")
# Out:
# ===================================
#  OVERALL ACCURACY MODEL HYBRID CRNN
# ===================================
# Overall Accuracy : 0.8803
# Overall Accuracy : 88.03%

# %% [markdown]
# ### Classification Report

# %%
print("=======================================================")
# Laporan Evaluasi Klasifikasi Multi-Kelas Spatio-Temporal
print("      CLASSIFICATION REPORT MODEL HYBRID CRNN SIBI     ")
print("=======================================================\n")

print(
    classification_report(
        Y_val,
        Y_pred_labels,
        target_names=target_names
    )
)
# Out:
# =======================================================
#       CLASSIFICATION REPORT MODEL HYBRID CRNN SIBI
# =======================================================
#
#               precision    recall  f1-score   support
#
#            A       1.00      0.89      0.94        18
#            B       1.00      1.00      1.00        18
#            C       0.75      1.00      0.86        18
#            D       1.00      1.00      1.00        18
#            E       0.90      1.00      0.95        18
#            F       1.00      1.00      1.00        18
#            G       0.25      0.67      0.36        18
#            H       0.92      0.67      0.77        18
#            I       1.00      0.89      0.94        18
#            J       1.00      0.89      0.94        18
#            K       1.00      1.00      1.00        18
#            L       0.95      1.00      0.97        18
#            M       0.00      0.00      0.00        18
#            N       0.00      0.00      0.00        18
#            O       1.00      1.00      1.00        18
#            P       0.95      1.00      0.97        18
#            Q       1.00      0.89      0.94        18
#            R       0.90      1.00      0.95        18
#            S       1.00      1.00      1.00        18
#            T       1.00      1.00      1.00        18
#            U       0.82      1.00      0.90        18
#            V       1.00      1.00      1.00        18
#            W       1.00      1.00      1.00        18
#            X       1.00      1.00      1.00        18
#            Y       1.00      1.00      1.00        18
#            Z       1.00      1.00      1.00        18
#
#     accuracy                           0.88       468
#    macro avg       0.86      0.88      0.87       468
# weighted avg       0.86      0.88      0.87       468

# %% [markdown]
# ### Bar Chart F1-Score CRNN

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

# 1. Ambil data report dalam bentuk dictionary (bukan string teks)
report_dict = classification_report(Y_val, Y_pred_labels, target_names=target_names, output_dict=True)

# 2. Ubah menjadi DataFrame pandas dan buang baris rangkuman (accuracy, macro avg, weighted avg)
df_report = pd.DataFrame(report_dict).transpose()
df_classes_only = df_report.loc[target_names] # Hanya mengambil baris A-Z

# 3. Plotting F1-Score tiap kelas menggunakan Bar Chart
plt.figure(figsize=(15, 6))
sns.barplot(
    x=df_classes_only.index, 
    y=df_classes_only['f1-score'], 
    palette='viridis'
)

plt.title('Grafik F1-Score Per Kelas Alfabet - Model CRNN SIBI', fontsize=14, fontweight='bold', pad=15)
plt.xlabel('Kelas Alfabet SIBI', fontsize=11)
plt.ylabel('F1-Score Value (0.0 - 1.0)', fontsize=11)
plt.ylim(0, 1.05) # Batas atas grafik
plt.grid(axis='y', linestyle='--', alpha=0.5)

# Tambahkan label nilai di atas setiap batang grafik
for i, val in enumerate(df_classes_only['f1-score']):
    plt.text(i, val + 0.01, f"{val:.2f}", ha='center', va='bottom', fontsize=9)

plt.tight_layout()

# Simpan gambar ke folder hasil_modelling
plt.savefig("hasil_modelling/rasio_90_10/crnn_f1_score_chart.png", dpi=300)
plt.show()

print("✓ Grafik batang F1-Score berhasil disimpan di 'hasil_modelling/rasio_90_10/crnn_f1_score_chart.png'")
# Out:
# /tmp/ipykernel_65632/1730770368.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# ✓ Grafik batang F1-Score berhasil disimpan di 'hasil_modelling/rasio_90_10/crnn_f1_score_chart.png'

# %% [markdown]
# ### Confusion Matrix

# %%
# 1. Hitung Confusion Matrix
cm = confusion_matrix(Y_val, Y_pred_labels)

# 2. Atur ukuran grafis gambar
plt.figure(figsize=(15, 12))

# 3. Gambar Heatmap menggunakan Seaborn
sns.heatmap(
    cm, 
    annot=True, 
    fmt='d', 
    cmap='Blues',
    xticklabels=target_names, 
    yticklabels=target_names,
    cbar=True,
    square=True
)

plt.title('Confusion Matrix Evaluasi Model Hybrid CRNN SIBI', fontsize=14, fontweight='bold', pad=20)
plt.xlabel('Label Prediksi Model', fontsize=12, labelpad=10)
plt.ylabel('Label Aktual (Grounded Truth)', fontsize=12, labelpad=10)
plt.xticks(rotation=0)
plt.yticks(rotation=0)
plt.tight_layout()

# 4. Simpan gambar secara fisik untuk disisipkan langsung ke Ms. Word Bab IV
plt.savefig('hasil_modelling/rasio_90_10/confusion_matrix_sibi.png', dpi=300)
plt.show()

print("✓ Grafik Confusion Matrix Berhasil Digambar dan Disimpan dengan nama 'confusion_matrix_sibi.png'!")
# Out:
# ✓ Grafik Confusion Matrix Berhasil Digambar dan Disimpan dengan nama 'confusion_matrix_sibi.png'!

# %% [markdown]
# # Pengujian

# %% [markdown]
# ### Prototype Deteksi SIBI

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
import mediapipe as mp

print("=== PROGRAM LIVE DEMO DETEKSI SIBI - CRNN (FIXED REAL-TIME) ===")

# 1. Muat Model Terbaik .keras
model_path = "hasil_modelling/rasio_90_10/best_sibi_crnn_model.keras"
if not os.path.exists(model_path):
    print(f" ERROR: File model '{model_path}' tidak ditemukan di folder ini!")
else:
    sibi_model = tf.keras.models.load_model(model_path)
    classes = [chr(i) for i in range(65, 91)] # ['A' s.d 'Z']
    print("✓ Model CRNN Berhasil Dimuat.")

    # 2. Inisialisasi Hand Landmarker Detector
    base_options = mp.tasks.BaseOptions(model_asset_path='../hasil_data_preparation/hand_landmarker.task')
    options = mp.tasks.vision.HandLandmarkerOptions(
        base_options=base_options,
        num_hands=1,
        min_hand_detection_confidence=0.5
    )
    detector = mp.tasks.vision.HandLandmarker.create_from_options(options)
    print("✓ MediaPipe Hand Landmarker Berhasil Diinisialisasi.")

    # 3. Konfigurasi Menembak Langsung ke Hardware Utama (/dev/video0)
    cap = cv2.VideoCapture('/dev/video0', cv2.CAP_V4L2)
    cap.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
    cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)

    frame_buffer = []
    predicted_letter = "Mencari Tangan..."
    confidence_score = 0.0

    print("\nMembuka Kamera... Tekan tombol 'q' pada JENDELA VIDEO untuk menutup Live Demo.")

    if not cap.isOpened():
        print(" ERROR: Gagal mengakses '/dev/video0'.")
        print("Buka terminal lalu jalankan perintah: sudo chmod 666 /dev/video0")
    else:
        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                print(" Koneksi kamera terputus atau frame kosong.")
                break
                
            frame = cv2.flip(frame, 1)
            h, w, c = frame.shape
            
            img_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            mp_image = mp.Image(image_format=mp.ImageFormat.SRGB, data=img_rgb)
            
            # Deteksi Landmark koordinat oleh MediaPipe Tasks
            detection_result = detector.detect(mp_image)
            frame_features = [0.0] * 63
            
            if detection_result.hand_landmarks:
                hand_landmarks = detection_result.hand_landmarks[0]
                frame_features = []
                for lm in hand_landmarks:
                    frame_features.extend([lm.x, lm.y, lm.z])
                    cx, cy = int(lm.x * w), int(lm.y * h)
                    cv2.circle(frame, (cx, cy), 4, (0, 255, 0), -1)
                    
            frame_buffer.append(frame_features)
            
            if len(frame_buffer) > 30:
                frame_buffer.pop(0)
                
            # Prediksi Runtunan Waktu Spatio-Temporal jika buffer window (30 frame) sudah penuh
            if len(frame_buffer) == 30:
                input_tensor = np.array([frame_buffer], dtype=np.float32)
                preds = sibi_model.predict(input_tensor, verbose=0)
                idx = np.argmax(preds[0])
                predicted_letter = classes[idx]
                confidence_score = preds[0][idx] * 100

            # Gambar HUD Overlay Informasi Hasil Prediksi
            cv2.rectangle(frame, (10, 10), (350, 85), (0, 0, 0), -1)
            cv2.putText(frame, f"Prediksi Isyarat: {predicted_letter}", (20, 40), 
                        cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 255), 2, cv2.LINE_AA)
            cv2.putText(frame, f"Presentase Ketepatan : {confidence_score:.2f}%", (20, 70), 
                        cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2, cv2.LINE_AA)
            
            # Tampilkan window aplikasi
            cv2.imshow("Live Demo Deteksi Bahasa Isyarat SIBI - CRNN", frame)
            
            # Berhenti jika menekan tombol 'q'
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break

        cap.release()
        cv2.destroyAllWindows()
        print("\n✓ Live Demo Pengujian Berhasil Ditutup Bersih.")
# Out:
# === PROGRAM LIVE DEMO DETEKSI SIBI - CRNN (FIXED REAL-TIME) ===
# ✓ Model CRNN Berhasil Dimuat.
# ✓ MediaPipe Hand Landmarker Berhasil Diinisialisasi.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1786565125.926042  108774 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1786565125.930761  108788 gl_context.cc:385] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.2.8-0ubuntu0.24.04.2), renderer: Mesa Intel(R) UHD Graphics (ICL GT1)
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1786565125.953477  108777 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1786565125.968360  108778 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Membuka Kamera... Tekan tombol 'q' pada JENDELA VIDEO untuk menutup Live Demo.
# W0000 00:00:1786565127.841360  108778 landmark_projection_calculator.cc:78] Using NORM_RECT without IMAGE_DIMENSIONS is only supported for the square ROI. Provide IMAGE_DIMENSIONS or use PROJECTION_MATRIX.
# QFontDatabase: Cannot find font directory /home/zacx/Downloads/SKRIPSI/Aplikasi/env/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/zacx/Downloads/SKRIPSI/Aplikasi/env/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/zacx/Downloads/SKRIPSI/Aplikasi/env/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/zacx/Downloads/SKRIPSI/Aplikasi/env/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/zacx/Downloads/SKRIPSI/Aplikasi/env/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# ✓ Live Demo Pengujian Berhasil Ditutup Bersih.
