# %% [markdown]
# # Modelling

# %% [markdown]
# ### Import Library Deep Learning

# %%
import os
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv1D, LSTM, Dense, Dropout, MaxPooling1D, BatchNormalization
from tensorflow.keras.callbacks import EarlyStopping, ReduceLROnPlateau, ModelCheckpoint
from sklearn.metrics import classification_report, confusion_matrix
import matplotlib.pyplot as plt
import seaborn as sns

print("✓ Pustaka Deep Learning Berhasil Dimuat!")
print("TensorFlow Version:", tf.__version__)
# Out:
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1786564424.601530   65638 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1786564424.602357   65638 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# I0000 00:00:1786564424.657758   65638 cpu_feature_guard.cc:227] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1786564427.438469   65638 port.cc:153] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# I0000 00:00:1786564427.438849   65638 cudart_stub.cc:31] Could not find cuda drivers on your machine, GPU will not be used.
# ✓ Pustaka Deep Learning Berhasil Dimuat!
# TensorFlow Version: 2.21.0

# %% [markdown]
# ### Memuat Data Hasil Ekstraksi

# %%
# Tentukan path lokasi folder tempat menyimpan file .npy
DATA_DIR = '../hasil_data_preparation/rasio_70_30'

# Load array koordinat spasio-temporal 3D
X_train = np.load(os.path.join(DATA_DIR, 'X_train_coor.npy'))
Y_train = np.load(os.path.join(DATA_DIR, 'Y_train_coor.npy'))
X_val = np.load(os.path.join(DATA_DIR, 'X_val_coor.npy'))
Y_val = np.load(os.path.join(DATA_DIR, 'Y_val_coor.npy'))

# Transformasi label integer (0-25) menjadi matriks biner One-Hot Encoding
num_classes = 26
Y_train_encoded = tf.keras.utils.to_categorical(Y_train, num_classes=num_classes)
Y_val_encoded = tf.keras.utils.to_categorical(Y_val, num_classes=num_classes)

print("=== VERIFIKASI DIMENSI MATRIKS UTAMA ===")
print(f"Shape X Latih      : {X_train.shape}")
print(f"Shape Y Latih Target: {Y_train_encoded.shape}")
print(f"\nShape X Validasi   : {X_val.shape}")
print(f"Shape Y Val Target : {Y_val_encoded.shape}")
# Out:
# === VERIFIKASI DIMENSI MATRIKS UTAMA ===
# Shape X Latih      : (3276, 30, 63)
# Shape Y Latih Target: (3276, 26)
#
# Shape X Validasi   : (1404, 30, 63)
# Shape Y Val Target : (1404, 26)

# %% [markdown]
# ### Perancangan Arsitektur Hybrid CRNN Spatio-Temporal

# %%
# ==========================================================
# 3.4.1.3 PERANCANGAN ARSITEKTUR HYBRID CRNN
# ==========================================================

def build_sibi_crnn(input_shape=(30, 63), num_classes=26):
    model = Sequential([
        
        # INPUT LAYER
        tf.keras.Input(shape=input_shape),

        # ==================================================
        # SPATIAL FEATURE EXTRACTION BLOCK (CONV1D)
        # ==================================================
        Conv1D(
            filters=64,
            kernel_size=3,
            activation='relu',
            padding='same'
        ),
        BatchNormalization(),
        MaxPooling1D(pool_size=2),
        Dropout(0.2),

        Conv1D(
            filters=128,
            kernel_size=3,
            activation='relu',
            padding='same'
        ),
        BatchNormalization(),
        MaxPooling1D(pool_size=2),
        Dropout(0.2),

        # ==================================================
        # TEMPORAL FEATURE EXTRACTION BLOCK (LSTM)
        # ==================================================
        LSTM(
            units=128,
            return_sequences=False
        ),
        Dropout(0.3),

        # ==================================================
        # CLASSIFIER BLOCK
        # ==================================================
        Dense(
            units=64,
            activation='relu'
        ),
        BatchNormalization(),
        Dropout(0.3),

        Dense(
            units=num_classes,
            activation='softmax'
        )
    ])

    return model


# Inisialisasi model CRNN
sibi_model = build_sibi_crnn(
    input_shape=(30, 63),
    num_classes=26
)

print("✓ Arsitektur Hybrid CRNN berhasil dibangun")
# Out:
# ✓ Arsitektur Hybrid CRNN berhasil dibangun
# E0000 00:00:1786564430.475846   65638 cuda_platform.cc:52] failed call to cuInit: INTERNAL: CUDA error: Failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected

# %% [markdown]
# ### Konfigurasi Kompilasi Model

# %%
# ==========================================================
# 3.4.1.4 KONFIGURASI KOMPILASI MODEL
# ==========================================================

sibi_model.compile(
    optimizer=tf.keras.optimizers.Adam(
        learning_rate=0.001
    ),
    loss='categorical_crossentropy',
    metrics=['accuracy']
)

print("✓ Model berhasil dikompilasi")
print("Optimizer      : Adam")
print("Learning Rate  : 0.001")
print("Loss Function  : categorical_crossentropy")
print("Metric         : accuracy")
# Out:
# ✓ Model berhasil dikompilasi
# Optimizer      : Adam
# Learning Rate  : 0.001
# Loss Function  : categorical_crossentropy
# Metric         : accuracy

# %% [markdown]
# ### Verifikasi Struktur Arsitektur Model

# %%
# ==========================================================
# 3.4.1.5 VERIFIKASI STRUKTUR ARSITEKTUR MODEL
# ==========================================================

print("======================================")
print(" RINGKASAN ARSITEKTUR HYBRID CRNN ")
print("======================================\n")

sibi_model.summary()
# Out:
# ======================================
#  RINGKASAN ARSITEKTUR HYBRID CRNN
# ======================================
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ conv1d (Conv1D)                 │ (None, 30, 64)         │        12,160 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization             │ (None, 30, 64)         │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d (MaxPooling1D)    │ (None, 15, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 15, 64)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ conv1d_1 (Conv1D)               │ (None, 15, 128)        │        24,704 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_1           │ (None, 15, 128)        │           512 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ max_pooling1d_1 (MaxPooling1D)  │ (None, 7, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 7, 128)         │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm (LSTM)                     │ (None, 128)            │       131,584 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ batch_normalization_2           │ (None, 64)             │           256 │
# │ (BatchNormalization)            │                        │               │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 26)             │         1,690 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 179,418 (700.85 KB)
#  Trainable params: 178,906 (698.85 KB)
#  Non-trainable params: 512 (2.00 KB)

# %% [markdown]
# ### Konfigurasi Strategi Pelatihan Model

# %%
# ==========================================================
# 3.4.1.6 KONFIGURASI STRATEGI PELATIHAN MODEL
# ==========================================================

# Lokasi penyimpanan model terbaik
checkpoint_path = "hasil_modelling/rasio_70_30/best_sibi_crnn_model.keras"

callbacks_list = [

    # Menghentikan training ketika val_loss stagnan
    EarlyStopping(
        monitor='val_loss',
        patience=15,
        restore_best_weights=True,
        verbose=1
    ),

    # Menurunkan learning rate secara otomatis
    ReduceLROnPlateau(
        monitor='val_loss',
        factor=0.5,
        patience=5,
        min_lr=1e-6,
        verbose=1
    ),

    # Menyimpan model terbaik
    ModelCheckpoint(
        filepath=checkpoint_path,
        monitor='val_accuracy',
        save_best_only=True,
        verbose=1
    )
]

print("✓ Strategi pelatihan model berhasil dikonfigurasi")
print("✓ EarlyStopping aktif")
print("✓ ReduceLROnPlateau aktif")
print("✓ ModelCheckpoint aktif")
# Out:
# ✓ Strategi pelatihan model berhasil dikonfigurasi
# ✓ EarlyStopping aktif
# ✓ ReduceLROnPlateau aktif
# ✓ ModelCheckpoint aktif

# %% [markdown]
# ### Pelatihan Model Hybrid CRNN

# %%
# ==========================================================
# 3.4.1.7 PELATIHAN MODEL HYBRID CRNN
# ==========================================================

EPOCHS = 100
BATCH_SIZE = 64

print("=========================================")
print(" MEMULAI PROSES PELATIHAN MODEL CRNN ")
print("=========================================\n")

history = sibi_model.fit(
    X_train,
    Y_train_encoded,
    validation_data=(
        X_val,
        Y_val_encoded
    ),
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    callbacks=callbacks_list,
    shuffle=True,
    verbose=1
)

print("\n✓ Proses pelatihan model selesai")
# Out:
# =========================================
#  MEMULAI PROSES PELATIHAN MODEL CRNN
# =========================================
#
# Epoch 1/100
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.3374 - loss: 2.4728
# Epoch 1: val_accuracy improved from None to 0.25427, saving model to hasil_modelling/rasio_70_30/best_sibi_crnn_model.keras
#
# Epoch 1: finished saving model to hasil_modelling/rasio_70_30/best_sibi_crnn_model.keras
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 6s 32ms/step - accuracy: 0.5266 - loss: 1.7132 - val_accuracy: 0.2543 - val_loss: 3.0307 - learning_rate: 0.0010
# Epoch 2/100
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.8163 - loss: 0.6945
# Epoch 2: val_accuracy did not improve from 0.25427
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.8342 - loss: 0.6076 - val_accuracy: 0.1923 - val_loss: 2.8699 - learning_rate: 0.0010
# Epoch 3/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8527 - loss: 0.4620
# Epoch 3: val_accuracy did not improve from 0.25427
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.8739 - loss: 0.4190 - val_accuracy: 0.1923 - val_loss: 2.7671 - learning_rate: 0.0010
# Epoch 4/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.8732 - loss: 0.4158
# Epoch 4: val_accuracy improved from 0.25427 to 0.27493, saving model to hasil_modelling/rasio_70_30/best_sibi_crnn_model.keras
#
# Epoch 4: finished saving model to hasil_modelling/rasio_70_30/best_sibi_crnn_model.keras
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 22ms/step - accuracy: 0.8803 - loss: 0.3777 - val_accuracy: 0.2749 - val_loss: 2.4591 - learning_rate: 0.0010
# Epoch 5/100
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.8964 - loss: 0.3118
# Epoch 5: val_accuracy improved from 0.27493 to 0.32336, saving model to hasil_modelling/rasio_70_30/best_sibi_crnn_model.keras
#
# Epoch 5: finished saving model to hasil_modelling/rasio_70_30/best_sibi_crnn_model.keras
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9020 - loss: 0.2916 - val_accuracy: 0.3234 - val_loss: 2.3597 - learning_rate: 0.0010
# Epoch 6/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9023 - loss: 0.2830
# Epoch 6: val_accuracy improved from 0.32336 to 0.56980, saving model to hasil_modelling/rasio_70_30/best_sibi_crnn_model.keras
#
# Epoch 6: finished saving model to hasil_modelling/rasio_70_30/best_sibi_crnn_model.keras
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9048 - loss: 0.2695 - val_accuracy: 0.5698 - val_loss: 1.5882 - learning_rate: 0.0010
# Epoch 7/100
# 49/52 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9060 - loss: 0.2520
# Epoch 7: val_accuracy did not improve from 0.56980
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9103 - loss: 0.2445 - val_accuracy: 0.4922 - val_loss: 1.7644 - learning_rate: 0.0010
# Epoch 8/100
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9080 - loss: 0.2494
# Epoch 8: val_accuracy improved from 0.56980 to 0.78989, saving model to hasil_modelling/rasio_70_30/best_sibi_crnn_model.keras
#
# Epoch 8: finished saving model to hasil_modelling/rasio_70_30/best_sibi_crnn_model.keras
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9106 - loss: 0.2449 - val_accuracy: 0.7899 - val_loss: 0.5862 - learning_rate: 0.0010
# Epoch 9/100
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9163 - loss: 0.2280
# Epoch 9: val_accuracy improved from 0.78989 to 0.79843, saving model to hasil_modelling/rasio_70_30/best_sibi_crnn_model.keras
#
# Epoch 9: finished saving model to hasil_modelling/rasio_70_30/best_sibi_crnn_model.keras
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9179 - loss: 0.2252 - val_accuracy: 0.7984 - val_loss: 0.6153 - learning_rate: 0.0010
# Epoch 10/100
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 20ms/step - accuracy: 0.9152 - loss: 0.2227
# Epoch 10: val_accuracy improved from 0.79843 to 0.81268, saving model to hasil_modelling/rasio_70_30/best_sibi_crnn_model.keras
#
# Epoch 10: finished saving model to hasil_modelling/rasio_70_30/best_sibi_crnn_model.keras
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 25ms/step - accuracy: 0.9188 - loss: 0.2136 - val_accuracy: 0.8127 - val_loss: 0.4091 - learning_rate: 0.0010
# Epoch 11/100
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9244 - loss: 0.2033
# Epoch 11: val_accuracy improved from 0.81268 to 0.82906, saving model to hasil_modelling/rasio_70_30/best_sibi_crnn_model.keras
#
# Epoch 11: finished saving model to hasil_modelling/rasio_70_30/best_sibi_crnn_model.keras
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9246 - loss: 0.2009 - val_accuracy: 0.8291 - val_loss: 0.3720 - learning_rate: 0.0010
# Epoch 12/100
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9277 - loss: 0.1990
# Epoch 12: val_accuracy did not improve from 0.82906
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9246 - loss: 0.1987 - val_accuracy: 0.7906 - val_loss: 0.5453 - learning_rate: 0.0010
# Epoch 13/100
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9309 - loss: 0.1860
# Epoch 13: val_accuracy improved from 0.82906 to 0.90670, saving model to hasil_modelling/rasio_70_30/best_sibi_crnn_model.keras
#
# Epoch 13: finished saving model to hasil_modelling/rasio_70_30/best_sibi_crnn_model.keras
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9292 - loss: 0.1824 - val_accuracy: 0.9067 - val_loss: 0.3337 - learning_rate: 0.0010
# Epoch 14/100
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9327 - loss: 0.1629
# Epoch 14: val_accuracy did not improve from 0.90670
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9243 - loss: 0.1816 - val_accuracy: 0.8326 - val_loss: 0.4465 - learning_rate: 0.0010
# Epoch 15/100
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9259 - loss: 0.1897
# Epoch 15: val_accuracy did not improve from 0.90670
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9289 - loss: 0.1787 - val_accuracy: 0.8312 - val_loss: 0.3790 - learning_rate: 0.0010
# Epoch 16/100
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9217 - loss: 0.1858
# Epoch 16: val_accuracy did not improve from 0.90670
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9280 - loss: 0.1778 - val_accuracy: 0.8697 - val_loss: 0.2862 - learning_rate: 0.0010
# Epoch 17/100
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9288 - loss: 0.1842
# Epoch 17: val_accuracy did not improve from 0.90670
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9274 - loss: 0.1872 - val_accuracy: 0.8283 - val_loss: 0.6040 - learning_rate: 0.0010
# Epoch 18/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9311 - loss: 0.1767
# Epoch 18: val_accuracy did not improve from 0.90670
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9277 - loss: 0.1851 - val_accuracy: 0.8326 - val_loss: 0.3874 - learning_rate: 0.0010
# Epoch 19/100
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9289 - loss: 0.1919
# Epoch 19: val_accuracy did not improve from 0.90670
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9270 - loss: 0.1853 - val_accuracy: 0.7165 - val_loss: 0.8224 - learning_rate: 0.0010
# Epoch 20/100
# 49/52 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9152 - loss: 0.2193
# Epoch 20: val_accuracy did not improve from 0.90670
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9170 - loss: 0.2179 - val_accuracy: 0.7308 - val_loss: 0.7899 - learning_rate: 0.0010
# Epoch 21/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9194 - loss: 0.1990
# Epoch 21: ReduceLROnPlateau reducing learning rate to 0.0005000000237487257.
#
# Epoch 21: val_accuracy did not improve from 0.90670
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9277 - loss: 0.1782 - val_accuracy: 0.8319 - val_loss: 0.4614 - learning_rate: 0.0010
# Epoch 22/100
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9286 - loss: 0.1803
# Epoch 22: val_accuracy did not improve from 0.90670
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9350 - loss: 0.1629 - val_accuracy: 0.8326 - val_loss: 0.3325 - learning_rate: 5.0000e-04
# Epoch 23/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9288 - loss: 0.1635
# Epoch 23: val_accuracy did not improve from 0.90670
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9301 - loss: 0.1632 - val_accuracy: 0.8711 - val_loss: 0.2717 - learning_rate: 5.0000e-04
# Epoch 24/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9302 - loss: 0.1642
# Epoch 24: val_accuracy did not improve from 0.90670
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9301 - loss: 0.1613 - val_accuracy: 0.8711 - val_loss: 0.2792 - learning_rate: 5.0000e-04
# Epoch 25/100
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9336 - loss: 0.1655
# Epoch 25: val_accuracy did not improve from 0.90670
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9335 - loss: 0.1622 - val_accuracy: 0.8711 - val_loss: 0.2769 - learning_rate: 5.0000e-04
# Epoch 26/100
# 49/52 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9315 - loss: 0.1635
# Epoch 26: val_accuracy did not improve from 0.90670
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9350 - loss: 0.1561 - val_accuracy: 0.8711 - val_loss: 0.2807 - learning_rate: 5.0000e-04
# Epoch 27/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9387 - loss: 0.1529
# Epoch 27: val_accuracy did not improve from 0.90670
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9344 - loss: 0.1576 - val_accuracy: 0.8326 - val_loss: 0.3963 - learning_rate: 5.0000e-04
# Epoch 28/100
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9298 - loss: 0.1675
# Epoch 28: ReduceLROnPlateau reducing learning rate to 0.0002500000118743628.
#
# Epoch 28: val_accuracy did not improve from 0.90670
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9350 - loss: 0.1603 - val_accuracy: 0.8711 - val_loss: 0.2767 - learning_rate: 5.0000e-04
# Epoch 29/100
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9214 - loss: 0.1864
# Epoch 29: val_accuracy did not improve from 0.90670
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9322 - loss: 0.1657 - val_accuracy: 0.8711 - val_loss: 0.2644 - learning_rate: 2.5000e-04
# Epoch 30/100
# 49/52 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9300 - loss: 0.1613
# Epoch 30: val_accuracy did not improve from 0.90670
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9338 - loss: 0.1585 - val_accuracy: 0.8711 - val_loss: 0.2667 - learning_rate: 2.5000e-04
# Epoch 31/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9350 - loss: 0.1625
# Epoch 31: val_accuracy did not improve from 0.90670
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9359 - loss: 0.1616 - val_accuracy: 0.8711 - val_loss: 0.2678 - learning_rate: 2.5000e-04
# Epoch 32/100
# 51/52 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9373 - loss: 0.1521
# Epoch 32: val_accuracy did not improve from 0.90670
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9341 - loss: 0.1573 - val_accuracy: 0.8711 - val_loss: 0.2650 - learning_rate: 2.5000e-04
# Epoch 33/100
# 49/52 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9369 - loss: 0.1558
# Epoch 33: val_accuracy did not improve from 0.90670
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9332 - loss: 0.1513 - val_accuracy: 0.8711 - val_loss: 0.2725 - learning_rate: 2.5000e-04
# Epoch 34/100
# 49/52 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9214 - loss: 0.1700
# Epoch 34: ReduceLROnPlateau reducing learning rate to 0.0001250000059371814.
#
# Epoch 34: val_accuracy did not improve from 0.90670
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9286 - loss: 0.1635 - val_accuracy: 0.8711 - val_loss: 0.2696 - learning_rate: 2.5000e-04
# Epoch 35/100
# 49/52 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9292 - loss: 0.1604
# Epoch 35: val_accuracy did not improve from 0.90670
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9332 - loss: 0.1551 - val_accuracy: 0.8711 - val_loss: 0.2723 - learning_rate: 1.2500e-04
# Epoch 36/100
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9243 - loss: 0.1682
# Epoch 36: val_accuracy did not improve from 0.90670
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9316 - loss: 0.1591 - val_accuracy: 0.8711 - val_loss: 0.2665 - learning_rate: 1.2500e-04
# Epoch 37/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9295 - loss: 0.1560
# Epoch 37: val_accuracy did not improve from 0.90670
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9292 - loss: 0.1587 - val_accuracy: 0.8711 - val_loss: 0.2700 - learning_rate: 1.2500e-04
# Epoch 38/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.9331 - loss: 0.1577
# Epoch 38: val_accuracy did not improve from 0.90670
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 20ms/step - accuracy: 0.9325 - loss: 0.1539 - val_accuracy: 0.8711 - val_loss: 0.2700 - learning_rate: 1.2500e-04
# Epoch 39/100
# 49/52 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9323 - loss: 0.1505
# Epoch 39: ReduceLROnPlateau reducing learning rate to 6.25000029685907e-05.
#
# Epoch 39: val_accuracy did not improve from 0.90670
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9350 - loss: 0.1536 - val_accuracy: 0.8711 - val_loss: 0.2692 - learning_rate: 1.2500e-04
# Epoch 40/100
# 50/52 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9313 - loss: 0.1557
# Epoch 40: val_accuracy did not improve from 0.90670
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 19ms/step - accuracy: 0.9325 - loss: 0.1574 - val_accuracy: 0.8711 - val_loss: 0.2705 - learning_rate: 6.2500e-05
# Epoch 41/100
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9398 - loss: 0.1456
# Epoch 41: val_accuracy did not improve from 0.90670
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9316 - loss: 0.1533 - val_accuracy: 0.8711 - val_loss: 0.2682 - learning_rate: 6.2500e-05
# Epoch 42/100
# 49/52 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9316 - loss: 0.1535
# Epoch 42: val_accuracy did not improve from 0.90670
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9301 - loss: 0.1564 - val_accuracy: 0.8711 - val_loss: 0.2675 - learning_rate: 6.2500e-05
# Epoch 43/100
# 49/52 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.9313 - loss: 0.1532
# Epoch 43: val_accuracy did not improve from 0.90670
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 18ms/step - accuracy: 0.9350 - loss: 0.1535 - val_accuracy: 0.8711 - val_loss: 0.2672 - learning_rate: 6.2500e-05
# Epoch 44/100
# 49/52 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.9284 - loss: 0.1730
# Epoch 44: ReduceLROnPlateau reducing learning rate to 3.125000148429535e-05.
#
# Epoch 44: val_accuracy did not improve from 0.90670
# 52/52 ━━━━━━━━━━━━━━━━━━━━ 1s 21ms/step - accuracy: 0.9328 - loss: 0.1559 - val_accuracy: 0.8711 - val_loss: 0.2678 - learning_rate: 6.2500e-05
# Epoch 44: early stopping
# Restoring model weights from the end of the best epoch: 29.
#
# ✓ Proses pelatihan model selesai

# %% [markdown]
# # Evaluasi Model

# %% [markdown]
# ## Evaluasi Kuantitatif

# %% [markdown]
# ### Grafik Performa Accuracy Curve

# %%
import os
import matplotlib.pyplot as plt

# Pastikan folder tersedia
os.makedirs("hasil_modelling/rasio_70_30", exist_ok=True)

# Ambil histori akurasi
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

epochs_range = range(1, len(acc) + 1)

# ==========================================================
# GRAFIK ACCURACY
# ==========================================================

plt.figure(figsize=(8, 5))

plt.plot(
    epochs_range,
    acc,
    label='Training Accuracy',
    linewidth=2
)

plt.plot(
    epochs_range,
    val_acc,
    label='Validation Accuracy',
    linewidth=2
)

plt.title(
    'Grafik Akurasi Pelatihan Model Hybrid CRNN',
    fontsize=12,
    fontweight='bold'
)

plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend(loc='lower right')

plt.grid(
    True,
    linestyle='--',
    alpha=0.6
)

plt.tight_layout()

# Simpan gambar
file_acc = "hasil_modelling/rasio_70_30/grafik_accuracy_crnn.png"

plt.savefig(
    file_acc,
    dpi=300,
    bbox_inches='tight'
)

plt.show()

print(f"✓ Grafik Accuracy tersimpan pada: {file_acc}")
# Out:
# ✓ Grafik Accuracy tersimpan pada: hasil_modelling/rasio_70_30/grafik_accuracy_crnn.png

# %% [markdown]
# ### Grafik Performa Loss Curve

# %%
import os
import matplotlib.pyplot as plt

# Pastikan folder tersedia
os.makedirs("hasil_modelling/rasio_70_30", exist_ok=True)

# Ambil histori loss
loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(1, len(loss) + 1)

# ==========================================================
# GRAFIK LOSS
# ==========================================================

plt.figure(figsize=(8, 5))

plt.plot(
    epochs_range,
    loss,
    label='Training Loss',
    linewidth=2
)

plt.plot(
    epochs_range,
    val_loss,
    label='Validation Loss',
    linewidth=2
)

plt.title(
    'Grafik Loss Pelatihan Model Hybrid CRNN',
    fontsize=12,
    fontweight='bold'
)

plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend(loc='upper right')

plt.grid(
    True,
    linestyle='--',
    alpha=0.6
)

plt.tight_layout()

# Simpan gambar
file_loss = "hasil_modelling/rasio_70_30/grafik_loss_crnn.png"

plt.savefig(
    file_loss,
    dpi=300,
    bbox_inches='tight'
)

plt.show()

print(f"✓ Grafik Loss tersimpan pada: {file_loss}")
# Out:
# ✓ Grafik Loss tersimpan pada: hasil_modelling/rasio_70_30/grafik_loss_crnn.png

# %% [markdown]
# ## Evaluasi Performa Klasifikasi

# %%
# ==========================================================
# PERSIAPAN HASIL PREDIKSI MODEL
# ==========================================================

Y_pred_prob = sibi_model.predict(X_val)

Y_pred_labels = np.argmax(
    Y_pred_prob,
    axis=1
)

target_names = [
    chr(i) for i in range(65, 91)
]

print("✓ Hasil prediksi model berhasil dibuat")
# Out:
# 44/44 ━━━━━━━━━━━━━━━━━━━━ 1s 9ms/step
# ✓ Hasil prediksi model berhasil dibuat

# %% [markdown]
# ### Overall Accuracy

# %%
from sklearn.metrics import accuracy_score

overall_accuracy = accuracy_score(
    Y_val,
    Y_pred_labels
)

print("===================================")
print(" OVERALL ACCURACY MODEL HYBRID CRNN ")
print("===================================")

print(f"Overall Accuracy : {overall_accuracy:.4f}")
print(f"Overall Accuracy : {overall_accuracy*100:.2f}%")
# Out:
# ===================================
#  OVERALL ACCURACY MODEL HYBRID CRNN
# ===================================
# Overall Accuracy : 0.8711
# Overall Accuracy : 87.11%

# %% [markdown]
# ### Classification Report

# %%
print("=======================================================")
# Laporan Evaluasi Klasifikasi Multi-Kelas Spatio-Temporal
print("      CLASSIFICATION REPORT MODEL HYBRID CRNN SIBI     ")
print("=======================================================\n")

print(
    classification_report(
        Y_val,
        Y_pred_labels,
        target_names=target_names
    )
)
# Out:
# =======================================================
#       CLASSIFICATION REPORT MODEL HYBRID CRNN SIBI
# =======================================================
#
#               precision    recall  f1-score   support
#
#            A       1.00      0.30      0.46        54
#            B       1.00      1.00      1.00        54
#            C       1.00      0.35      0.52        54
#            D       1.00      1.00      1.00        54
#            E       1.00      1.00      1.00        54
#            F       1.00      1.00      1.00        54
#            G       0.23      1.00      0.37        54
#            H       1.00      1.00      1.00        54
#            I       1.00      1.00      1.00        54
#            J       1.00      1.00      1.00        54
#            K       1.00      1.00      1.00        54
#            L       1.00      1.00      1.00        54
#            M       0.00      0.00      0.00        54
#            N       0.00      0.00      0.00        54
#            O       1.00      1.00      1.00        54
#            P       1.00      1.00      1.00        54
#            Q       1.00      1.00      1.00        54
#            R       1.00      1.00      1.00        54
#            S       1.00      1.00      1.00        54
#            T       1.00      1.00      1.00        54
#            U       1.00      1.00      1.00        54
#            V       1.00      1.00      1.00        54
#            W       1.00      1.00      1.00        54
#            X       1.00      1.00      1.00        54
#            Y       1.00      1.00      1.00        54
#            Z       1.00      1.00      1.00        54
#
#     accuracy                           0.87      1404
#    macro avg       0.89      0.87      0.86      1404
# weighted avg       0.89      0.87      0.86      1404
# /home/zacx/Downloads/SKRIPSI/Aplikasi/env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/zacx/Downloads/SKRIPSI/Aplikasi/env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/zacx/Downloads/SKRIPSI/Aplikasi/env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %% [markdown]
# ### Bar Chart F1-Score CRNN

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.metrics import classification_report

# 1. Ambil data report dalam bentuk dictionary (bukan string teks)
report_dict = classification_report(Y_val, Y_pred_labels, target_names=target_names, output_dict=True)

# 2. Ubah menjadi DataFrame pandas dan buang baris rangkuman (accuracy, macro avg, weighted avg)
df_report = pd.DataFrame(report_dict).transpose()
df_classes_only = df_report.loc[target_names] # Hanya mengambil baris A-Z

# 3. Plotting F1-Score tiap kelas menggunakan Bar Chart
plt.figure(figsize=(15, 6))
sns.barplot(
    x=df_classes_only.index, 
    y=df_classes_only['f1-score'], 
    palette='viridis'
)

plt.title('Grafik F1-Score Per Kelas Alfabet - Model CRNN SIBI', fontsize=14, fontweight='bold', pad=15)
plt.xlabel('Kelas Alfabet SIBI', fontsize=11)
plt.ylabel('F1-Score Value (0.0 - 1.0)', fontsize=11)
plt.ylim(0, 1.05) # Batas atas grafik
plt.grid(axis='y', linestyle='--', alpha=0.5)

# Tambahkan label nilai di atas setiap batang grafik
for i, val in enumerate(df_classes_only['f1-score']):
    plt.text(i, val + 0.01, f"{val:.2f}", ha='center', va='bottom', fontsize=9)

plt.tight_layout()

# Simpan gambar ke folder hasil_modelling
plt.savefig("hasil_modelling/rasio_70_30/crnn_f1_score_chart.png", dpi=300)
plt.show()

print("✓ Grafik batang F1-Score berhasil disimpan di 'hasil_modelling/crnn_f1_score_chart.png'")
# Out:
# /home/zacx/Downloads/SKRIPSI/Aplikasi/env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/zacx/Downloads/SKRIPSI/Aplikasi/env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/zacx/Downloads/SKRIPSI/Aplikasi/env/lib/python3.12/site-packages/sklearn/metrics/_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /tmp/ipykernel_65638/219007298.py:15: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(
# ✓ Grafik batang F1-Score berhasil disimpan di 'hasil_modelling/crnn_f1_score_chart.png'

# %% [markdown]
# ### Confusion Matrix

# %%
# 1. Hitung Confusion Matrix
cm = confusion_matrix(Y_val, Y_pred_labels)

# 2. Atur ukuran grafis gambar
plt.figure(figsize=(15, 12))

# 3. Gambar Heatmap menggunakan Seaborn
sns.heatmap(
    cm, 
    annot=True, 
    fmt='d', 
    cmap='Blues',
    xticklabels=target_names, 
    yticklabels=target_names,
    cbar=True,
    square=True
)

plt.title('Confusion Matrix Evaluasi Model Hybrid CRNN SIBI', fontsize=14, fontweight='bold', pad=20)
plt.xlabel('Label Prediksi Model', fontsize=12, labelpad=10)
plt.ylabel('Label Aktual (Grounded Truth)', fontsize=12, labelpad=10)
plt.xticks(rotation=0)
plt.yticks(rotation=0)
plt.tight_layout()

# 4. Simpan gambar secara fisik untuk disisipkan langsung ke Ms. Word Bab IV
plt.savefig('hasil_modelling/rasio_70_30/confusion_matrix_sibi.png', dpi=300)
plt.show()

print("✓ Grafik Confusion Matrix Berhasil Digambar dan Disimpan dengan nama 'confusion_matrix_sibi.png'!")
# Out:
# ✓ Grafik Confusion Matrix Berhasil Digambar dan Disimpan dengan nama 'confusion_matrix_sibi.png'!

# %% [markdown]
# # Pengujian

# %% [markdown]
# ### Prototype Deteksi SIBI

# %%
import os
import cv2
import numpy as np
import tensorflow as tf
import mediapipe as mp

print("=== PROGRAM LIVE DEMO DETEKSI SIBI - CRNN (FIXED REAL-TIME) ===")

# 1. Muat Model Terbaik .keras
model_path = "hasil_modelling/rasio_70_30/best_sibi_crnn_model.keras"
if not os.path.exists(model_path):
    print(f" ERROR: File model '{model_path}' tidak ditemukan di folder ini!")
else:
    sibi_model = tf.keras.models.load_model(model_path)
    classes = [chr(i) for i in range(65, 91)] # ['A' s.d 'Z']
    print("✓ Model CRNN Berhasil Dimuat.")

    # 2. Inisialisasi Hand Landmarker Detector
    base_options = mp.tasks.BaseOptions(model_asset_path='../hasil_data_preparation/hand_landmarker.task')
    options = mp.tasks.vision.HandLandmarkerOptions(
        base_options=base_options,
        num_hands=1,
        min_hand_detection_confidence=0.5
    )
    detector = mp.tasks.vision.HandLandmarker.create_from_options(options)
    print("✓ MediaPipe Hand Landmarker Berhasil Diinisialisasi.")

    # 3. Konfigurasi Menembak Langsung ke Hardware Utama (/dev/video0)
    cap = cv2.VideoCapture('/dev/video0', cv2.CAP_V4L2)
    cap.set(cv2.CAP_PROP_FRAME_WIDTH, 640)
    cap.set(cv2.CAP_PROP_FRAME_HEIGHT, 480)

    frame_buffer = []
    predicted_letter = "Mencari Tangan..."
    confidence_score = 0.0

    print("\nMembuka Kamera... Tekan tombol 'q' pada JENDELA VIDEO untuk menutup Live Demo.")

    if not cap.isOpened():
        print(" ERROR: Gagal mengakses '/dev/video0'.")
        print("Buka terminal lalu jalankan perintah: sudo chmod 666 /dev/video0")
    else:
        while cap.isOpened():
            ret, frame = cap.read()
            if not ret:
                print(" Koneksi kamera terputus atau frame kosong.")
                break
                
            frame = cv2.flip(frame, 1)
            h, w, c = frame.shape
            
            img_rgb = cv2.cvtColor(frame, cv2.COLOR_BGR2RGB)
            mp_image = mp.Image(image_format=mp.ImageFormat.SRGB, data=img_rgb)
            
            # Deteksi Landmark koordinat oleh MediaPipe Tasks
            detection_result = detector.detect(mp_image)
            frame_features = [0.0] * 63
            
            if detection_result.hand_landmarks:
                hand_landmarks = detection_result.hand_landmarks[0]
                frame_features = []
                for lm in hand_landmarks:
                    frame_features.extend([lm.x, lm.y, lm.z])
                    cx, cy = int(lm.x * w), int(lm.y * h)
                    cv2.circle(frame, (cx, cy), 4, (0, 255, 0), -1)
                    
            frame_buffer.append(frame_features)
            
            if len(frame_buffer) > 30:
                frame_buffer.pop(0)
                
            # Prediksi Runtunan Waktu Spatio-Temporal jika buffer window (30 frame) sudah penuh
            if len(frame_buffer) == 30:
                input_tensor = np.array([frame_buffer], dtype=np.float32)
                preds = sibi_model.predict(input_tensor, verbose=0)
                idx = np.argmax(preds[0])
                predicted_letter = classes[idx]
                confidence_score = preds[0][idx] * 100

            # Gambar HUD Overlay Informasi Hasil Prediksi
            cv2.rectangle(frame, (10, 10), (350, 85), (0, 0, 0), -1)
            cv2.putText(frame, f"Prediksi Isyarat: {predicted_letter}", (20, 40), 
                        cv2.FONT_HERSHEY_SIMPLEX, 0.9, (0, 255, 255), 2, cv2.LINE_AA)
            cv2.putText(frame, f"Presentase Ketepatan : {confidence_score:.2f}%", (20, 70), 
                        cv2.FONT_HERSHEY_SIMPLEX, 0.7, (0, 255, 0), 2, cv2.LINE_AA)
            
            # Tampilkan window aplikasi
            cv2.imshow("Live Demo Deteksi Bahasa Isyarat SIBI - CRNN", frame)
            
            # Berhenti jika menekan tombol 'q'
            if cv2.waitKey(1) & 0xFF == ord('q'):
                break

        cap.release()
        cv2.destroyAllWindows()
        print("\n✓ Live Demo Pengujian Berhasil Ditutup Bersih.")
# Out:
# === PROGRAM LIVE DEMO DETEKSI SIBI - CRNN (FIXED REAL-TIME) ===
# ✓ Model CRNN Berhasil Dimuat.
# ✓ MediaPipe Hand Landmarker Berhasil Diinisialisasi.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1786565144.522566  108804 gl_context_egl.cc:85] Successfully initialized EGL. Major : 1 Minor: 5
# I0000 00:00:1786565144.526127  108818 gl_context.cc:385] GL version: 3.2 (OpenGL ES 3.2 Mesa 25.2.8-0ubuntu0.24.04.2), renderer: Mesa Intel(R) UHD Graphics (ICL GT1)
# INFO: Created TensorFlow Lite XNNPACK delegate for CPU.
# W0000 00:00:1786565144.551977  108806 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# W0000 00:00:1786565144.568087  108812 inference_feedback_manager.cc:114] Feedback manager requires a model with a single signature inference. Disabling support for feedback tensors.
# Membuka Kamera... Tekan tombol 'q' pada JENDELA VIDEO untuk menutup Live Demo.
# W0000 00:00:1786565146.439142  108809 landmark_projection_calculator.cc:78] Using NORM_RECT without IMAGE_DIMENSIONS is only supported for the square ROI. Provide IMAGE_DIMENSIONS or use PROJECTION_MATRIX.
# QFontDatabase: Cannot find font directory /home/zacx/Downloads/SKRIPSI/Aplikasi/env/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/zacx/Downloads/SKRIPSI/Aplikasi/env/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/zacx/Downloads/SKRIPSI/Aplikasi/env/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/zacx/Downloads/SKRIPSI/Aplikasi/env/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# QFontDatabase: Cannot find font directory /home/zacx/Downloads/SKRIPSI/Aplikasi/env/lib/python3.12/site-packages/cv2/qt/fonts.
# Note that Qt no longer ships fonts. Deploy some (from https://dejavu-fonts.github.io/ for example) or switch to fontconfig.
# ✓ Live Demo Pengujian Berhasil Ditutup Bersih.
